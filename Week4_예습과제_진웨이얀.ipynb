# %%
# To ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # GBM(Gradient Boosting Machine)

# %%
def get_new_feature_name_df(old_feature_name_df):
    feature_dup_df = pd.DataFrame(data=old_feature_name_df.groupby('column_name').cumcount(),
                                  columns=['dup_cnt'])
    feature_dup_df = feature_dup_df.reset_index()
    new_feature_name_df = pd.merge(old_feature_name_df.reset_index(), feature_dup_df, how='outer')
    new_feature_name_df['column_name'] = new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x : x[0]+'_'+str(x[1]) 
                                                                                         if x[1] >0 else x[0] ,  axis=1)
    new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
    return new_feature_name_df

# %%
import pandas as pd

def get_human_dataset( ):
    feature_name_df = pd.read_csv('./human_activity/features.txt',sep='\s+',
                        header=None,names=['column_index','column_name'])
    # Change duplicate data names (name, name -> name1,name2)
    new_feature_name_df = get_new_feature_name_df(feature_name_df)
    
    feature_name = new_feature_name_df.iloc[:, 1].values.tolist()
    
    X_train = pd.read_csv('./human_activity/train/X_train.txt',sep='\s+', names=feature_name )
    X_test = pd.read_csv('./human_activity/test/X_test.txt',sep='\s+', names=feature_name)
    
    y_train = pd.read_csv('./human_activity/train/y_train.txt',sep='\s+',header=None,names=['action'])
    y_test = pd.read_csv('./human_activity/test/y_test.txt',sep='\s+',header=None,names=['action'])
    
    return X_train, X_test, y_train, y_test

# %%
from sklearn.ensemble import GradientBoostingClassifier
import time
from sklearn.metrics import accuracy_score

# Get dataset
X_train, X_test, y_train, y_test = get_human_dataset()
# to check time
start_time = time.time()

# Train
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train,y_train)
# Predict
gb_pred = gb_clf.predict(X_test)
# Evaluate
accuracy_score = accuracy_score(y_test,gb_pred)

print('GBM 정확도: {:.4f}'.format(accuracy_score))
print('GBM 수행 시간: {:.1f}'.format(time.time()-start_time))
# Out:
# GBM 정확도: 0.9382
# GBM 수행 시간: 575.9

# %% [markdown]
# # XGBoost(eXtra Gradient Boost)

# %%
# Importing xgboost to check whether it works or not
import xgboost as xgb
from xgboost import XGBClassifier

# %% [markdown]
# ## 파이썬 래퍼 XGBoost

# %%
# Import xgboost
import xgboost
# Check version
print(xgboost.__version__)
# Out:
# 3.0.0

# %% [markdown]
# ### 파이썬 래퍼 XGBoost 적용 - 위스콘신 유방암 예측

# %%
# Import 
import xgboost as xgb
from xgboost import plot_importance
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# Load dataset
dataset = load_breast_cancer()
# Feature
features = dataset.data
# Label
labels = dataset.target
# Change into dataframe
# insert feature
cancer_df = pd.DataFrame(data=features, columns=dataset.feature_names)
# insert label
cancer_df['target'] = labels

cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
# Check label's distribution
print(dataset.target_names)
print(cancer_df['target'].value_counts())
# Out:
# ['malignant' 'benign']
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
# Extract feature DataFrame & label series 
X_features = cancer_df.iloc[:,:-1]
y_label = cancer_df.iloc[:,-1]

# Extract Train data(80%) Test data(20%) from dataset
X_train, X_test, y_train, y_test = train_test_split(X_features,y_label,test_size=0.2,random_state=156)

# Split Train data(90%) Validation data(10%) from Train data
X_tr, X_val, y_tr, y_val = train_test_split(X_train,y_train,test_size=0.1,random_state=156)

# Before splitting into validation
print(X_train.shape, X_test.shape)
# After splitting into validation
print(X_tr.shape, y_tr.shape)
# Out:
# (455, 30) (114, 30)
# (409, 30) (409,)

# %%
# Python Wrapper XGBoost's 전용 데이터 객체 : DMatrix
# DMatrix for Train, Validation, Test 
dtr = xgb.DMatrix(data=X_tr,label=y_tr)
dval = xgb.DMatrix(data=X_val,label=y_val)
dtest = xgb.DMatrix(data=X_test,label=y_test)

# %%
# Setting XGBoost hyper parameters
params = {
    'max_depth' : 3,
    'eta' : 0.05, #learning rate
    'objective' : 'binary:logistic',
    'eval_metric' : 'logloss'
}
num_rounds = 400

# %%
# Setting Evaluation dataset 
# Train dataset -> 'train', Validation dataset -> 'eval'
eval_list = [(dtr,'train'),(dval,'eval')] 
# eval_list = [(dval,'eval')]

# Train
xgb_model = xgb.train(params=params, dtrain=dtr, early_stopping_rounds=50, num_boost_round=num_rounds, evals=eval_list)

# decreasing of loss stopped at 126 but as early_stopping_rounds=50, it goes till 176 and then it does not see decreasing so it rlly stopped
# Out:
# [0]	train-logloss:0.62473	eval-logloss:0.63088
# [1]	train-logloss:0.58662	eval-logloss:0.60461
# [2]	train-logloss:0.55210	eval-logloss:0.58205
# [3]	train-logloss:0.52068	eval-logloss:0.56165
# [4]	train-logloss:0.49173	eval-logloss:0.54101
# [5]	train-logloss:0.46517	eval-logloss:0.52206
# [6]	train-logloss:0.44009	eval-logloss:0.50271
# [7]	train-logloss:0.41646	eval-logloss:0.48606
# [8]	train-logloss:0.39505	eval-logloss:0.46961
# [9]	train-logloss:0.37523	eval-logloss:0.45485
# [10]	train-logloss:0.35682	eval-logloss:0.44120
# [11]	train-logloss:0.33964	eval-logloss:0.43123
# [12]	train-logloss:0.32279	eval-logloss:0.41962
# [13]	train-logloss:0.30783	eval-logloss:0.40848
# [14]	train-logloss:0.29308	eval-logloss:0.39857
# [15]	train-logloss:0.27928	eval-logloss:0.38945
# [16]	train-logloss:0.26681	eval-logloss:0.38171
# [17]	train-logloss:0.25498	eval-logloss:0.37381
# [18]	train-logloss:0.24352	eval-logloss:0.36656
# [19]	train-logloss:0.23307	eval-logloss:0.36014
# [20]	train-logloss:0.22290	eval-logloss:0.35395
# [21]	train-logloss:0.21335	eval-logloss:0.34726
# [22]	train-logloss:0.20461	eval-logloss:0.34194
# [23]	train-logloss:0.19610	eval-logloss:0.33611
# [24]	train-logloss:0.18807	eval-logloss:0.33170
# [25]	train-logloss:0.18054	eval-logloss:0.32730
# [26]	train-logloss:0.17336	eval-logloss:0.32357
# [27]	train-logloss:0.16659	eval-logloss:0.31915
# [28]	train-logloss:0.16021	eval-logloss:0.31569
# [29]	train-logloss:0.15417	eval-logloss:0.31236
# [30]	train-logloss:0.14843	eval-logloss:0.30978
# [31]	train-logloss:0.14298	eval-logloss:0.30645
# [32]	train-logloss:0.13788	eval-logloss:0.30403
# [33]	train-logloss:0.13299	eval-logloss:0.30108
# [34]	train-logloss:0.12824	eval-logloss:0.29780
# [35]	train-logloss:0.12392	eval-logloss:0.29599
# [36]	train-logloss:0.11965	eval-logloss:0.29444
# [37]	train-logloss:0.11549	eval-logloss:0.29141
# [38]	train-logloss:0.11168	eval-logloss:0.28951
# [39]	train-logloss:0.10797	eval-logloss:0.28751
# [40]	train-logloss:0.10458	eval-logloss:0.28600
# [41]	train-logloss:0.10116	eval-logloss:0.28381
# [42]	train-logloss:0.09801	eval-logloss:0.28226
# [43]	train-logloss:0.09494	eval-logloss:0.28086
# [44]	train-logloss:0.09211	eval-logloss:0.27937
# [45]	train-logloss:0.08939	eval-logloss:0.27746
# [46]	train-logloss:0.08688	eval-logloss:0.27717
# [47]	train-logloss:0.08441	eval-logloss:0.27523
# [48]	train-logloss:0.08205	eval-logloss:0.27367
# [49]	train-logloss:0.07981	eval-logloss:0.27254
# [50]	train-logloss:0.07767	eval-logloss:0.27090
# [51]	train-logloss:0.07565	eval-logloss:0.26996
# [52]	train-logloss:0.07354	eval-logloss:0.26984
# [53]	train-logloss:0.07169	eval-logloss:0.26846
# [54]	train-logloss:0.06994	eval-logloss:0.26778
# [55]	train-logloss:0.06822	eval-logloss:0.26653
# [56]	train-logloss:0.06661	eval-logloss:0.26614
# [57]	train-logloss:0.06509	eval-logloss:0.26509
# [58]	train-logloss:0.06359	eval-logloss:0.26497
# [59]	train-logloss:0.06218	eval-logloss:0.26424
# [60]	train-logloss:0.06056	eval-logloss:0.26369
# [61]	train-logloss:0.05909	eval-logloss:0.26197
# [62]	train-logloss:0.05782	eval-logloss:0.26091
# [63]	train-logloss:0.05648	eval-logloss:0.25936
# [64]	train-logloss:0.05511	eval-logloss:0.25881
# [65]	train-logloss:0.05383	eval-logloss:0.25837
# [66]	train-logloss:0.05257	eval-logloss:0.25740
# [67]	train-logloss:0.05132	eval-logloss:0.25701
# [68]	train-logloss:0.05034	eval-logloss:0.25595
# [69]	train-logloss:0.04901	eval-logloss:0.25522
# [70]	train-logloss:0.04804	eval-logloss:0.25551
# [71]	train-logloss:0.04702	eval-logloss:0.25487
# [72]	train-logloss:0.04614	eval-logloss:0.25409
# [73]	train-logloss:0.04518	eval-logloss:0.25447
# [74]	train-logloss:0.04426	eval-logloss:0.25393
# [75]	train-logloss:0.04337	eval-logloss:0.25386
# [76]	train-logloss:0.04252	eval-logloss:0.25397
# [77]	train-logloss:0.04168	eval-logloss:0.25278
# [78]	train-logloss:0.04082	eval-logloss:0.25285
# [79]	train-logloss:0.04005	eval-logloss:0.25188
# [80]	train-logloss:0.03926	eval-logloss:0.25276
# [81]	train-logloss:0.03849	eval-logloss:0.25294
# [82]	train-logloss:0.03774	eval-logloss:0.25376
# [83]	train-logloss:0.03712	eval-logloss:0.25441
# [84]	train-logloss:0.03648	eval-logloss:0.25474
# [85]	train-logloss:0.03578	eval-logloss:0.25497
# [86]	train-logloss:0.03523	eval-logloss:0.25566
# [87]	train-logloss:0.03458	eval-logloss:0.25602
# [88]	train-logloss:0.03396	eval-logloss:0.25629
# [89]	train-logloss:0.03336	eval-logloss:0.25574
# [90]	train-logloss:0.03287	eval-logloss:0.25647
# [91]	train-logloss:0.03230	eval-logloss:0.25598
# [92]	train-logloss:0.03175	eval-logloss:0.25617
# [93]	train-logloss:0.03127	eval-logloss:0.25538
# [94]	train-logloss:0.03077	eval-logloss:0.25641
# [95]	train-logloss:0.03026	eval-logloss:0.25600
# [96]	train-logloss:0.02978	eval-logloss:0.25560
# [97]	train-logloss:0.02938	eval-logloss:0.25513
# [98]	train-logloss:0.02889	eval-logloss:0.25448
# [99]	train-logloss:0.02844	eval-logloss:0.25416
# [100]	train-logloss:0.02802	eval-logloss:0.25385
# [101]	train-logloss:0.02764	eval-logloss:0.25426
# [102]	train-logloss:0.02724	eval-logloss:0.25400
# [103]	train-logloss:0.02685	eval-logloss:0.25220
# [104]	train-logloss:0.02648	eval-logloss:0.25196
# [105]	train-logloss:0.02611	eval-logloss:0.25253
# [106]	train-logloss:0.02578	eval-logloss:0.25141
# [107]	train-logloss:0.02542	eval-logloss:0.25168
# [108]	train-logloss:0.02509	eval-logloss:0.25203
# [109]	train-logloss:0.02476	eval-logloss:0.25219
# [110]	train-logloss:0.02441	eval-logloss:0.25187
# [111]	train-logloss:0.02403	eval-logloss:0.25063
# [112]	train-logloss:0.02372	eval-logloss:0.25121
# [113]	train-logloss:0.02339	eval-logloss:0.24862
# [114]	train-logloss:0.02310	eval-logloss:0.24922
# [115]	train-logloss:0.02279	eval-logloss:0.24903
# [116]	train-logloss:0.02248	eval-logloss:0.24924
# [117]	train-logloss:0.02217	eval-logloss:0.24756
# [118]	train-logloss:0.02191	eval-logloss:0.24720
# [119]	train-logloss:0.02162	eval-logloss:0.24566
# [120]	train-logloss:0.02134	eval-logloss:0.24629
# [121]	train-logloss:0.02105	eval-logloss:0.24693
# [122]	train-logloss:0.02078	eval-logloss:0.24755
# [123]	train-logloss:0.02056	eval-logloss:0.24753
# [124]	train-logloss:0.02030	eval-logloss:0.24738
# [125]	train-logloss:0.02007	eval-logloss:0.24705
# [126]	train-logloss:0.01984	eval-logloss:0.24741
# [127]	train-logloss:0.01961	eval-logloss:0.24802
# [128]	train-logloss:0.01940	eval-logloss:0.24716
# [129]	train-logloss:0.01916	eval-logloss:0.24701
# [130]	train-logloss:0.01896	eval-logloss:0.24752
# [131]	train-logloss:0.01872	eval-logloss:0.24758
# [132]	train-logloss:0.01853	eval-logloss:0.24849
# [133]	train-logloss:0.01834	eval-logloss:0.24890
# [134]	train-logloss:0.01820	eval-logloss:0.24902
# [135]	train-logloss:0.01799	eval-logloss:0.24769
# [136]	train-logloss:0.01778	eval-logloss:0.24756
# [137]	train-logloss:0.01761	eval-logloss:0.24762
# [138]	train-logloss:0.01747	eval-logloss:0.24686
# [139]	train-logloss:0.01730	eval-logloss:0.24724
# [140]	train-logloss:0.01710	eval-logloss:0.24713
# [141]	train-logloss:0.01696	eval-logloss:0.24720
# [142]	train-logloss:0.01680	eval-logloss:0.24761
# [143]	train-logloss:0.01662	eval-logloss:0.24731
# [144]	train-logloss:0.01649	eval-logloss:0.24659
# [145]	train-logloss:0.01634	eval-logloss:0.24643
# [146]	train-logloss:0.01617	eval-logloss:0.24615
# [147]	train-logloss:0.01606	eval-logloss:0.24626
# [148]	train-logloss:0.01591	eval-logloss:0.24614
# [149]	train-logloss:0.01579	eval-logloss:0.24545
# [150]	train-logloss:0.01562	eval-logloss:0.24621
# [151]	train-logloss:0.01549	eval-logloss:0.24607
# [152]	train-logloss:0.01532	eval-logloss:0.24596
# [153]	train-logloss:0.01521	eval-logloss:0.24530
# [154]	train-logloss:0.01505	eval-logloss:0.24583
# [155]	train-logloss:0.01493	eval-logloss:0.24570
# [156]	train-logloss:0.01476	eval-logloss:0.24642
# [157]	train-logloss:0.01462	eval-logloss:0.24623
# [158]	train-logloss:0.01447	eval-logloss:0.24670
# [159]	train-logloss:0.01435	eval-logloss:0.24659
# [160]	train-logloss:0.01423	eval-logloss:0.24548
# [161]	train-logloss:0.01415	eval-logloss:0.24485
# [162]	train-logloss:0.01399	eval-logloss:0.24547
# [163]	train-logloss:0.01387	eval-logloss:0.24545
# [164]	train-logloss:0.01372	eval-logloss:0.24608
# [165]	train-logloss:0.01359	eval-logloss:0.24507
# [166]	train-logloss:0.01351	eval-logloss:0.24484
# [167]	train-logloss:0.01340	eval-logloss:0.24484
# [168]	train-logloss:0.01326	eval-logloss:0.24547
# [169]	train-logloss:0.01315	eval-logloss:0.24443
# [170]	train-logloss:0.01305	eval-logloss:0.24488
# [171]	train-logloss:0.01297	eval-logloss:0.24478
# [172]	train-logloss:0.01289	eval-logloss:0.24422
# [173]	train-logloss:0.01282	eval-logloss:0.24414
# [174]	train-logloss:0.01272	eval-logloss:0.24317
# [175]	train-logloss:0.01263	eval-logloss:0.24326
# [176]	train-logloss:0.01256	eval-logloss:0.24273
# [177]	train-logloss:0.01247	eval-logloss:0.24262
# [178]	train-logloss:0.01237	eval-logloss:0.24309
# [179]	train-logloss:0.01231	eval-logloss:0.24250
# [180]	train-logloss:0.01224	eval-logloss:0.24243
# [181]	train-logloss:0.01215	eval-logloss:0.24148
# [182]	train-logloss:0.01206	eval-logloss:0.24136
# [183]	train-logloss:0.01199	eval-logloss:0.24130
# [184]	train-logloss:0.01191	eval-logloss:0.24141
# [185]	train-logloss:0.01183	eval-logloss:0.24045
# [186]	train-logloss:0.01177	eval-logloss:0.23950
# [187]	train-logloss:0.01171	eval-logloss:0.23946
# [188]	train-logloss:0.01165	eval-logloss:0.23943
# [189]	train-logloss:0.01156	eval-logloss:0.23954
# [190]	train-logloss:0.01151	eval-logloss:0.23897
# [191]	train-logloss:0.01145	eval-logloss:0.23961
# [192]	train-logloss:0.01138	eval-logloss:0.23972
# [193]	train-logloss:0.01133	eval-logloss:0.23968
# [194]	train-logloss:0.01128	eval-logloss:0.23913
# [195]	train-logloss:0.01121	eval-logloss:0.23924
# [196]	train-logloss:0.01118	eval-logloss:0.23902
# [197]	train-logloss:0.01113	eval-logloss:0.23900
# [198]	train-logloss:0.01106	eval-logloss:0.23912
# [199]	train-logloss:0.01101	eval-logloss:0.23824
# [200]	train-logloss:0.01096	eval-logloss:0.23802
# [201]	train-logloss:0.01090	eval-logloss:0.23814
# [202]	train-logloss:0.01086	eval-logloss:0.23762
# [203]	train-logloss:0.01080	eval-logloss:0.23740
# [204]	train-logloss:0.01074	eval-logloss:0.23752
# [205]	train-logloss:0.01069	eval-logloss:0.23793
# [206]	train-logloss:0.01064	eval-logloss:0.23797
# [207]	train-logloss:0.01058	eval-logloss:0.23803
# [208]	train-logloss:0.01054	eval-logloss:0.23782
# [209]	train-logloss:0.01048	eval-logloss:0.23793
# [210]	train-logloss:0.01045	eval-logloss:0.23773
# [211]	train-logloss:0.01041	eval-logloss:0.23814
# [212]	train-logloss:0.01036	eval-logloss:0.23817
# [213]	train-logloss:0.01031	eval-logloss:0.23866
# [214]	train-logloss:0.01027	eval-logloss:0.23926
# [215]	train-logloss:0.01025	eval-logloss:0.23907
# [216]	train-logloss:0.01019	eval-logloss:0.23842
# [217]	train-logloss:0.01014	eval-logloss:0.23845
# [218]	train-logloss:0.01011	eval-logloss:0.23866
# [219]	train-logloss:0.01009	eval-logloss:0.23842
# [220]	train-logloss:0.01007	eval-logloss:0.23823
# [221]	train-logloss:0.01003	eval-logloss:0.23844
# [222]	train-logloss:0.01001	eval-logloss:0.23836
# [223]	train-logloss:0.00996	eval-logloss:0.23855
# [224]	train-logloss:0.00993	eval-logloss:0.23876
# [225]	train-logloss:0.00991	eval-logloss:0.23857
# [226]	train-logloss:0.00989	eval-logloss:0.23833
# [227]	train-logloss:0.00986	eval-logloss:0.23855
# [228]	train-logloss:0.00984	eval-logloss:0.23837
# [229]	train-logloss:0.00982	eval-logloss:0.23813
# [230]	train-logloss:0.00979	eval-logloss:0.23862
# [231]	train-logloss:0.00977	eval-logloss:0.23844
# [232]	train-logloss:0.00975	eval-logloss:0.23836
# [233]	train-logloss:0.00971	eval-logloss:0.23882
# [234]	train-logloss:0.00968	eval-logloss:0.23935
# [235]	train-logloss:0.00962	eval-logloss:0.23870
# [236]	train-logloss:0.00958	eval-logloss:0.23873
# [237]	train-logloss:0.00956	eval-logloss:0.23855
# [238]	train-logloss:0.00953	eval-logloss:0.23877
# [239]	train-logloss:0.00952	eval-logloss:0.23854
# [240]	train-logloss:0.00950	eval-logloss:0.23901
# [241]	train-logloss:0.00948	eval-logloss:0.23899
# [242]	train-logloss:0.00947	eval-logloss:0.23881
# [243]	train-logloss:0.00944	eval-logloss:0.23903
# [244]	train-logloss:0.00942	eval-logloss:0.23895
# [245]	train-logloss:0.00938	eval-logloss:0.23951
# [246]	train-logloss:0.00934	eval-logloss:0.23996
# [247]	train-logloss:0.00932	eval-logloss:0.23978
# [248]	train-logloss:0.00930	eval-logloss:0.24030
# [249]	train-logloss:0.00928	eval-logloss:0.24008
# [250]	train-logloss:0.00926	eval-logloss:0.24054
# [251]	train-logloss:0.00925	eval-logloss:0.24046
# [252]	train-logloss:0.00921	eval-logloss:0.24055
# [253]	train-logloss:0.00919	eval-logloss:0.24053

# %%
# Predict
# xgboost's predict() return probability(not value)
pred_proba = xgb_model.predict(dtest)
print('predict() 수행 결괏값을 10개만 표시, 예측 확률 값으로 표시됨')
print(np.round(pred_proba[:10],3))

# Change probability into 1,0 -> if greater than 0.5 : 1 else : 0
pred = [1 if i>0.5 else 0 for i in pred_proba]
print("예측값 10개만 표시:",pred[:10])
# Out:
# predict() 수행 결괏값을 10개만 표시, 예측 확률 값으로 표시됨
# [0.938 0.004 0.776 0.058 0.975 1.    0.999 0.999 0.998 0.   ]
# 예측값 10개만 표시: [1, 0, 1, 0, 1, 1, 1, 1, 1, 0]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
# Evaluate
get_clf_eval(y_test,pred,pred_proba)
# Out:
# 오차 행렬
# [[35  2]
#  [ 2 75]]
# 정확도: 0.9649, 정밀도: 0.9740, 재현율: 0.9740,    F1: 0.9740, AUC:0.9965

# %%
# Plotting Important features
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

# fig:entire figure, ax:specific subplot(to pass as para)
fig, ax = plt.subplots(figsize=(10,12))
plot_importance(xgb_model,ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %% [markdown]
# ## 사이킷런 래퍼 XGBoost

# %%
# Import XGBClassifier(Scikit-learn wrapper XGBoost class)
from xgboost import XGBClassifier

# %% [markdown]
# ### 사이킷런 래퍼 XGBoost 적용 - 위스콘신 유방암 예측

# %%
# Without Early Stopping
from xgboost import XGBClassifier
# Train
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05,max_depth=3,eval_metric='logloss')
xgb_wrapper.fit(X_train,y_train,verbose=True)
# Predict
w_pred = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1] #extract only 1

# %%
xgb_wrapper.predict_proba(X_test)[:3]
# Out:
# array([[0.09329373, 0.9067063 ],
#        [0.9967079 , 0.00329211],
#        [0.0940302 , 0.9059698 ]], dtype=float32)

# %%
# Evaluate
get_clf_eval(y_test,w_pred,w_pred_proba)
# Out:
# 오차 행렬
# [[34  3]
#  [ 1 76]]
# 정확도: 0.9649, 정밀도: 0.9620, 재현율: 0.9870,    F1: 0.9744, AUC:0.9951

# %%
# Early Stooping Round : 50
evals = [(X_tr,y_tr),(X_val,y_val)]
# Train
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05,max_depth=3, early_stopping_rounds=50, eval_metric='logloss')
xgb_wrapper.fit(X_tr,y_tr,eval_set=evals, verbose=True)
# Predict
ws50_pred = xgb_wrapper.predict(X_test)
ws50_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]
# Out:
# [0]	validation_0-logloss:0.62473	validation_1-logloss:0.63088
# [1]	validation_0-logloss:0.58662	validation_1-logloss:0.60461
# [2]	validation_0-logloss:0.55210	validation_1-logloss:0.58205
# [3]	validation_0-logloss:0.52068	validation_1-logloss:0.56165
# [4]	validation_0-logloss:0.49173	validation_1-logloss:0.54101
# [5]	validation_0-logloss:0.46517	validation_1-logloss:0.52206
# [6]	validation_0-logloss:0.44009	validation_1-logloss:0.50271
# [7]	validation_0-logloss:0.41646	validation_1-logloss:0.48606
# [8]	validation_0-logloss:0.39505	validation_1-logloss:0.46961
# [9]	validation_0-logloss:0.37523	validation_1-logloss:0.45485
# [10]	validation_0-logloss:0.35682	validation_1-logloss:0.44120
# [11]	validation_0-logloss:0.33964	validation_1-logloss:0.43123
# [12]	validation_0-logloss:0.32279	validation_1-logloss:0.41962
# [13]	validation_0-logloss:0.30783	validation_1-logloss:0.40848
# [14]	validation_0-logloss:0.29308	validation_1-logloss:0.39857
# [15]	validation_0-logloss:0.27928	validation_1-logloss:0.38945
# [16]	validation_0-logloss:0.26681	validation_1-logloss:0.38171
# [17]	validation_0-logloss:0.25498	validation_1-logloss:0.37381
# [18]	validation_0-logloss:0.24352	validation_1-logloss:0.36656
# [19]	validation_0-logloss:0.23307	validation_1-logloss:0.36014
# [20]	validation_0-logloss:0.22290	validation_1-logloss:0.35395
# [21]	validation_0-logloss:0.21335	validation_1-logloss:0.34726
# [22]	validation_0-logloss:0.20461	validation_1-logloss:0.34194
# [23]	validation_0-logloss:0.19610	validation_1-logloss:0.33611
# [24]	validation_0-logloss:0.18807	validation_1-logloss:0.33170
# [25]	validation_0-logloss:0.18054	validation_1-logloss:0.32730
# [26]	validation_0-logloss:0.17336	validation_1-logloss:0.32357
# [27]	validation_0-logloss:0.16659	validation_1-logloss:0.31915
# [28]	validation_0-logloss:0.16021	validation_1-logloss:0.31569
# [29]	validation_0-logloss:0.15417	validation_1-logloss:0.31236
# [30]	validation_0-logloss:0.14843	validation_1-logloss:0.30978
# [31]	validation_0-logloss:0.14298	validation_1-logloss:0.30645
# [32]	validation_0-logloss:0.13788	validation_1-logloss:0.30403
# [33]	validation_0-logloss:0.13299	validation_1-logloss:0.30108
# [34]	validation_0-logloss:0.12824	validation_1-logloss:0.29780
# [35]	validation_0-logloss:0.12392	validation_1-logloss:0.29599
# [36]	validation_0-logloss:0.11965	validation_1-logloss:0.29444
# [37]	validation_0-logloss:0.11549	validation_1-logloss:0.29141
# [38]	validation_0-logloss:0.11168	validation_1-logloss:0.28951
# [39]	validation_0-logloss:0.10797	validation_1-logloss:0.28751
# [40]	validation_0-logloss:0.10458	validation_1-logloss:0.28600
# [41]	validation_0-logloss:0.10116	validation_1-logloss:0.28381
# [42]	validation_0-logloss:0.09801	validation_1-logloss:0.28226
# [43]	validation_0-logloss:0.09494	validation_1-logloss:0.28086
# [44]	validation_0-logloss:0.09211	validation_1-logloss:0.27937
# [45]	validation_0-logloss:0.08939	validation_1-logloss:0.27746
# [46]	validation_0-logloss:0.08688	validation_1-logloss:0.27717
# [47]	validation_0-logloss:0.08441	validation_1-logloss:0.27523
# [48]	validation_0-logloss:0.08205	validation_1-logloss:0.27367
# [49]	validation_0-logloss:0.07981	validation_1-logloss:0.27254
# [50]	validation_0-logloss:0.07767	validation_1-logloss:0.27090
# [51]	validation_0-logloss:0.07565	validation_1-logloss:0.26996
# [52]	validation_0-logloss:0.07354	validation_1-logloss:0.26984
# [53]	validation_0-logloss:0.07169	validation_1-logloss:0.26846
# [54]	validation_0-logloss:0.06994	validation_1-logloss:0.26778
# [55]	validation_0-logloss:0.06822	validation_1-logloss:0.26653
# [56]	validation_0-logloss:0.06661	validation_1-logloss:0.26614
# [57]	validation_0-logloss:0.06509	validation_1-logloss:0.26509
# [58]	validation_0-logloss:0.06359	validation_1-logloss:0.26497
# [59]	validation_0-logloss:0.06218	validation_1-logloss:0.26424
# [60]	validation_0-logloss:0.06056	validation_1-logloss:0.26369
# [61]	validation_0-logloss:0.05909	validation_1-logloss:0.26197
# [62]	validation_0-logloss:0.05782	validation_1-logloss:0.26091
# [63]	validation_0-logloss:0.05648	validation_1-logloss:0.25936
# [64]	validation_0-logloss:0.05511	validation_1-logloss:0.25881
# [65]	validation_0-logloss:0.05383	validation_1-logloss:0.25837
# [66]	validation_0-logloss:0.05257	validation_1-logloss:0.25740
# [67]	validation_0-logloss:0.05132	validation_1-logloss:0.25701
# [68]	validation_0-logloss:0.05034	validation_1-logloss:0.25595
# [69]	validation_0-logloss:0.04901	validation_1-logloss:0.25522
# [70]	validation_0-logloss:0.04804	validation_1-logloss:0.25551
# [71]	validation_0-logloss:0.04702	validation_1-logloss:0.25487
# [72]	validation_0-logloss:0.04614	validation_1-logloss:0.25409
# [73]	validation_0-logloss:0.04518	validation_1-logloss:0.25447
# [74]	validation_0-logloss:0.04426	validation_1-logloss:0.25393
# [75]	validation_0-logloss:0.04337	validation_1-logloss:0.25386
# [76]	validation_0-logloss:0.04252	validation_1-logloss:0.25397
# [77]	validation_0-logloss:0.04168	validation_1-logloss:0.25278
# [78]	validation_0-logloss:0.04082	validation_1-logloss:0.25285
# [79]	validation_0-logloss:0.04005	validation_1-logloss:0.25188
# [80]	validation_0-logloss:0.03926	validation_1-logloss:0.25276
# [81]	validation_0-logloss:0.03849	validation_1-logloss:0.25294
# [82]	validation_0-logloss:0.03774	validation_1-logloss:0.25376
# [83]	validation_0-logloss:0.03712	validation_1-logloss:0.25441
# [84]	validation_0-logloss:0.03648	validation_1-logloss:0.25474
# [85]	validation_0-logloss:0.03578	validation_1-logloss:0.25497
# [86]	validation_0-logloss:0.03523	validation_1-logloss:0.25566
# [87]	validation_0-logloss:0.03458	validation_1-logloss:0.25602
# [88]	validation_0-logloss:0.03396	validation_1-logloss:0.25629
# [89]	validation_0-logloss:0.03336	validation_1-logloss:0.25574
# [90]	validation_0-logloss:0.03287	validation_1-logloss:0.25647
# [91]	validation_0-logloss:0.03230	validation_1-logloss:0.25598
# [92]	validation_0-logloss:0.03175	validation_1-logloss:0.25617
# [93]	validation_0-logloss:0.03127	validation_1-logloss:0.25538
# [94]	validation_0-logloss:0.03077	validation_1-logloss:0.25641
# [95]	validation_0-logloss:0.03026	validation_1-logloss:0.25600
# [96]	validation_0-logloss:0.02978	validation_1-logloss:0.25560
# [97]	validation_0-logloss:0.02938	validation_1-logloss:0.25513
# [98]	validation_0-logloss:0.02889	validation_1-logloss:0.25448
# [99]	validation_0-logloss:0.02844	validation_1-logloss:0.25416
# [100]	validation_0-logloss:0.02802	validation_1-logloss:0.25385
# [101]	validation_0-logloss:0.02764	validation_1-logloss:0.25426
# [102]	validation_0-logloss:0.02724	validation_1-logloss:0.25400
# [103]	validation_0-logloss:0.02685	validation_1-logloss:0.25220
# [104]	validation_0-logloss:0.02648	validation_1-logloss:0.25196
# [105]	validation_0-logloss:0.02611	validation_1-logloss:0.25253
# [106]	validation_0-logloss:0.02578	validation_1-logloss:0.25141
# [107]	validation_0-logloss:0.02542	validation_1-logloss:0.25168
# [108]	validation_0-logloss:0.02509	validation_1-logloss:0.25203
# [109]	validation_0-logloss:0.02476	validation_1-logloss:0.25219
# [110]	validation_0-logloss:0.02441	validation_1-logloss:0.25187
# [111]	validation_0-logloss:0.02403	validation_1-logloss:0.25063
# [112]	validation_0-logloss:0.02372	validation_1-logloss:0.25121
# [113]	validation_0-logloss:0.02339	validation_1-logloss:0.24862
# [114]	validation_0-logloss:0.02310	validation_1-logloss:0.24922
# [115]	validation_0-logloss:0.02279	validation_1-logloss:0.24903
# [116]	validation_0-logloss:0.02248	validation_1-logloss:0.24924
# [117]	validation_0-logloss:0.02217	validation_1-logloss:0.24756
# [118]	validation_0-logloss:0.02191	validation_1-logloss:0.24720
# [119]	validation_0-logloss:0.02162	validation_1-logloss:0.24566
# [120]	validation_0-logloss:0.02134	validation_1-logloss:0.24629
# [121]	validation_0-logloss:0.02105	validation_1-logloss:0.24693
# [122]	validation_0-logloss:0.02078	validation_1-logloss:0.24755
# [123]	validation_0-logloss:0.02056	validation_1-logloss:0.24753
# [124]	validation_0-logloss:0.02030	validation_1-logloss:0.24738
# [125]	validation_0-logloss:0.02007	validation_1-logloss:0.24705
# [126]	validation_0-logloss:0.01984	validation_1-logloss:0.24741
# [127]	validation_0-logloss:0.01961	validation_1-logloss:0.24802
# [128]	validation_0-logloss:0.01940	validation_1-logloss:0.24716
# [129]	validation_0-logloss:0.01916	validation_1-logloss:0.24701
# [130]	validation_0-logloss:0.01896	validation_1-logloss:0.24752
# [131]	validation_0-logloss:0.01872	validation_1-logloss:0.24758
# [132]	validation_0-logloss:0.01853	validation_1-logloss:0.24849
# [133]	validation_0-logloss:0.01834	validation_1-logloss:0.24890
# [134]	validation_0-logloss:0.01820	validation_1-logloss:0.24902
# [135]	validation_0-logloss:0.01799	validation_1-logloss:0.24769
# [136]	validation_0-logloss:0.01778	validation_1-logloss:0.24756
# [137]	validation_0-logloss:0.01761	validation_1-logloss:0.24762
# [138]	validation_0-logloss:0.01747	validation_1-logloss:0.24686
# [139]	validation_0-logloss:0.01730	validation_1-logloss:0.24724
# [140]	validation_0-logloss:0.01710	validation_1-logloss:0.24713
# [141]	validation_0-logloss:0.01696	validation_1-logloss:0.24720
# [142]	validation_0-logloss:0.01680	validation_1-logloss:0.24761
# [143]	validation_0-logloss:0.01662	validation_1-logloss:0.24731
# [144]	validation_0-logloss:0.01649	validation_1-logloss:0.24659
# [145]	validation_0-logloss:0.01634	validation_1-logloss:0.24643
# [146]	validation_0-logloss:0.01617	validation_1-logloss:0.24615
# [147]	validation_0-logloss:0.01606	validation_1-logloss:0.24626
# [148]	validation_0-logloss:0.01591	validation_1-logloss:0.24614
# [149]	validation_0-logloss:0.01579	validation_1-logloss:0.24545
# [150]	validation_0-logloss:0.01562	validation_1-logloss:0.24621
# [151]	validation_0-logloss:0.01549	validation_1-logloss:0.24607
# [152]	validation_0-logloss:0.01532	validation_1-logloss:0.24596
# [153]	validation_0-logloss:0.01521	validation_1-logloss:0.24530
# [154]	validation_0-logloss:0.01505	validation_1-logloss:0.24583
# [155]	validation_0-logloss:0.01493	validation_1-logloss:0.24570
# [156]	validation_0-logloss:0.01476	validation_1-logloss:0.24642
# [157]	validation_0-logloss:0.01462	validation_1-logloss:0.24623
# [158]	validation_0-logloss:0.01447	validation_1-logloss:0.24670
# [159]	validation_0-logloss:0.01435	validation_1-logloss:0.24659
# [160]	validation_0-logloss:0.01423	validation_1-logloss:0.24548
# [161]	validation_0-logloss:0.01415	validation_1-logloss:0.24485
# [162]	validation_0-logloss:0.01399	validation_1-logloss:0.24547
# [163]	validation_0-logloss:0.01387	validation_1-logloss:0.24545
# [164]	validation_0-logloss:0.01372	validation_1-logloss:0.24608
# [165]	validation_0-logloss:0.01359	validation_1-logloss:0.24507
# [166]	validation_0-logloss:0.01351	validation_1-logloss:0.24484
# [167]	validation_0-logloss:0.01340	validation_1-logloss:0.24484
# [168]	validation_0-logloss:0.01326	validation_1-logloss:0.24547
# [169]	validation_0-logloss:0.01315	validation_1-logloss:0.24443
# [170]	validation_0-logloss:0.01305	validation_1-logloss:0.24488
# [171]	validation_0-logloss:0.01297	validation_1-logloss:0.24478
# [172]	validation_0-logloss:0.01289	validation_1-logloss:0.24422
# [173]	validation_0-logloss:0.01282	validation_1-logloss:0.24414
# [174]	validation_0-logloss:0.01272	validation_1-logloss:0.24317
# [175]	validation_0-logloss:0.01263	validation_1-logloss:0.24326
# [176]	validation_0-logloss:0.01256	validation_1-logloss:0.24273
# [177]	validation_0-logloss:0.01247	validation_1-logloss:0.24262
# [178]	validation_0-logloss:0.01237	validation_1-logloss:0.24309
# [179]	validation_0-logloss:0.01231	validation_1-logloss:0.24250
# [180]	validation_0-logloss:0.01224	validation_1-logloss:0.24243
# [181]	validation_0-logloss:0.01215	validation_1-logloss:0.24148
# [182]	validation_0-logloss:0.01206	validation_1-logloss:0.24136
# [183]	validation_0-logloss:0.01199	validation_1-logloss:0.24130
# [184]	validation_0-logloss:0.01191	validation_1-logloss:0.24141
# [185]	validation_0-logloss:0.01183	validation_1-logloss:0.24045
# [186]	validation_0-logloss:0.01177	validation_1-logloss:0.23950
# [187]	validation_0-logloss:0.01171	validation_1-logloss:0.23946
# [188]	validation_0-logloss:0.01165	validation_1-logloss:0.23943
# [189]	validation_0-logloss:0.01156	validation_1-logloss:0.23954
# [190]	validation_0-logloss:0.01151	validation_1-logloss:0.23897
# [191]	validation_0-logloss:0.01145	validation_1-logloss:0.23961
# [192]	validation_0-logloss:0.01138	validation_1-logloss:0.23972
# [193]	validation_0-logloss:0.01133	validation_1-logloss:0.23968
# [194]	validation_0-logloss:0.01128	validation_1-logloss:0.23913
# [195]	validation_0-logloss:0.01121	validation_1-logloss:0.23924
# [196]	validation_0-logloss:0.01118	validation_1-logloss:0.23902
# [197]	validation_0-logloss:0.01113	validation_1-logloss:0.23900
# [198]	validation_0-logloss:0.01106	validation_1-logloss:0.23912
# [199]	validation_0-logloss:0.01101	validation_1-logloss:0.23824
# [200]	validation_0-logloss:0.01096	validation_1-logloss:0.23802
# [201]	validation_0-logloss:0.01090	validation_1-logloss:0.23814
# [202]	validation_0-logloss:0.01086	validation_1-logloss:0.23762
# [203]	validation_0-logloss:0.01080	validation_1-logloss:0.23740
# [204]	validation_0-logloss:0.01074	validation_1-logloss:0.23752
# [205]	validation_0-logloss:0.01069	validation_1-logloss:0.23793
# [206]	validation_0-logloss:0.01064	validation_1-logloss:0.23797
# [207]	validation_0-logloss:0.01058	validation_1-logloss:0.23803
# [208]	validation_0-logloss:0.01054	validation_1-logloss:0.23782
# [209]	validation_0-logloss:0.01048	validation_1-logloss:0.23793
# [210]	validation_0-logloss:0.01045	validation_1-logloss:0.23773
# [211]	validation_0-logloss:0.01041	validation_1-logloss:0.23814
# [212]	validation_0-logloss:0.01036	validation_1-logloss:0.23817
# [213]	validation_0-logloss:0.01031	validation_1-logloss:0.23866
# [214]	validation_0-logloss:0.01027	validation_1-logloss:0.23926
# [215]	validation_0-logloss:0.01025	validation_1-logloss:0.23907
# [216]	validation_0-logloss:0.01019	validation_1-logloss:0.23842
# [217]	validation_0-logloss:0.01014	validation_1-logloss:0.23845
# [218]	validation_0-logloss:0.01011	validation_1-logloss:0.23866
# [219]	validation_0-logloss:0.01009	validation_1-logloss:0.23842
# [220]	validation_0-logloss:0.01007	validation_1-logloss:0.23823
# [221]	validation_0-logloss:0.01003	validation_1-logloss:0.23844
# [222]	validation_0-logloss:0.01001	validation_1-logloss:0.23836
# [223]	validation_0-logloss:0.00996	validation_1-logloss:0.23855
# [224]	validation_0-logloss:0.00993	validation_1-logloss:0.23876
# [225]	validation_0-logloss:0.00991	validation_1-logloss:0.23857
# [226]	validation_0-logloss:0.00989	validation_1-logloss:0.23833
# [227]	validation_0-logloss:0.00986	validation_1-logloss:0.23855
# [228]	validation_0-logloss:0.00984	validation_1-logloss:0.23837
# [229]	validation_0-logloss:0.00982	validation_1-logloss:0.23813
# [230]	validation_0-logloss:0.00979	validation_1-logloss:0.23862
# [231]	validation_0-logloss:0.00977	validation_1-logloss:0.23844
# [232]	validation_0-logloss:0.00975	validation_1-logloss:0.23836
# [233]	validation_0-logloss:0.00971	validation_1-logloss:0.23882
# [234]	validation_0-logloss:0.00968	validation_1-logloss:0.23935
# [235]	validation_0-logloss:0.00962	validation_1-logloss:0.23870
# [236]	validation_0-logloss:0.00958	validation_1-logloss:0.23873
# [237]	validation_0-logloss:0.00956	validation_1-logloss:0.23855
# [238]	validation_0-logloss:0.00953	validation_1-logloss:0.23877
# [239]	validation_0-logloss:0.00952	validation_1-logloss:0.23854
# [240]	validation_0-logloss:0.00950	validation_1-logloss:0.23901
# [241]	validation_0-logloss:0.00948	validation_1-logloss:0.23899
# [242]	validation_0-logloss:0.00947	validation_1-logloss:0.23881
# [243]	validation_0-logloss:0.00944	validation_1-logloss:0.23903
# [244]	validation_0-logloss:0.00942	validation_1-logloss:0.23895
# [245]	validation_0-logloss:0.00938	validation_1-logloss:0.23951
# [246]	validation_0-logloss:0.00934	validation_1-logloss:0.23996
# [247]	validation_0-logloss:0.00932	validation_1-logloss:0.23978
# [248]	validation_0-logloss:0.00930	validation_1-logloss:0.24030
# [249]	validation_0-logloss:0.00928	validation_1-logloss:0.24008
# [250]	validation_0-logloss:0.00926	validation_1-logloss:0.24054
# [251]	validation_0-logloss:0.00925	validation_1-logloss:0.24046
# [252]	validation_0-logloss:0.00921	validation_1-logloss:0.24055
# [253]	validation_0-logloss:0.00919	validation_1-logloss:0.24053

# %%
# Evaluate
get_clf_eval(y_test,ws50_pred,ws50_pred_proba)
# Out:
# 오차 행렬
# [[35  2]
#  [ 2 75]]
# 정확도: 0.9649, 정밀도: 0.9740, 재현율: 0.9740,    F1: 0.9740, AUC:0.9965

# %%
# Early Stooping Round : 10
# Train
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05,max_depth=3, early_stopping_rounds=10, eval_metric='logloss')
xgb_wrapper.fit(X_tr,y_tr,eval_set=evals, verbose=True)
# Predict
ws10_pred = xgb_wrapper.predict(X_test)
ws10_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]

get_clf_eval(y_test,ws10_pred,ws10_pred_proba)
# Out:
# [0]	validation_0-logloss:0.62473	validation_1-logloss:0.63088
# [1]	validation_0-logloss:0.58662	validation_1-logloss:0.60461
# [2]	validation_0-logloss:0.55210	validation_1-logloss:0.58205
# [3]	validation_0-logloss:0.52068	validation_1-logloss:0.56165
# [4]	validation_0-logloss:0.49173	validation_1-logloss:0.54101
# [5]	validation_0-logloss:0.46517	validation_1-logloss:0.52206
# [6]	validation_0-logloss:0.44009	validation_1-logloss:0.50271
# [7]	validation_0-logloss:0.41646	validation_1-logloss:0.48606
# [8]	validation_0-logloss:0.39505	validation_1-logloss:0.46961
# [9]	validation_0-logloss:0.37523	validation_1-logloss:0.45485
# [10]	validation_0-logloss:0.35682	validation_1-logloss:0.44120
# [11]	validation_0-logloss:0.33964	validation_1-logloss:0.43123
# [12]	validation_0-logloss:0.32279	validation_1-logloss:0.41962
# [13]	validation_0-logloss:0.30783	validation_1-logloss:0.40848
# [14]	validation_0-logloss:0.29308	validation_1-logloss:0.39857
# [15]	validation_0-logloss:0.27928	validation_1-logloss:0.38945
# [16]	validation_0-logloss:0.26681	validation_1-logloss:0.38171
# [17]	validation_0-logloss:0.25498	validation_1-logloss:0.37381
# [18]	validation_0-logloss:0.24352	validation_1-logloss:0.36656
# [19]	validation_0-logloss:0.23307	validation_1-logloss:0.36014
# [20]	validation_0-logloss:0.22290	validation_1-logloss:0.35395
# [21]	validation_0-logloss:0.21335	validation_1-logloss:0.34726
# [22]	validation_0-logloss:0.20461	validation_1-logloss:0.34194
# [23]	validation_0-logloss:0.19610	validation_1-logloss:0.33611
# [24]	validation_0-logloss:0.18807	validation_1-logloss:0.33170
# [25]	validation_0-logloss:0.18054	validation_1-logloss:0.32730
# [26]	validation_0-logloss:0.17336	validation_1-logloss:0.32357
# [27]	validation_0-logloss:0.16659	validation_1-logloss:0.31915
# [28]	validation_0-logloss:0.16021	validation_1-logloss:0.31569
# [29]	validation_0-logloss:0.15417	validation_1-logloss:0.31236
# [30]	validation_0-logloss:0.14843	validation_1-logloss:0.30978
# [31]	validation_0-logloss:0.14298	validation_1-logloss:0.30645
# [32]	validation_0-logloss:0.13788	validation_1-logloss:0.30403
# [33]	validation_0-logloss:0.13299	validation_1-logloss:0.30108
# [34]	validation_0-logloss:0.12824	validation_1-logloss:0.29780
# [35]	validation_0-logloss:0.12392	validation_1-logloss:0.29599
# [36]	validation_0-logloss:0.11965	validation_1-logloss:0.29444
# [37]	validation_0-logloss:0.11549	validation_1-logloss:0.29141
# [38]	validation_0-logloss:0.11168	validation_1-logloss:0.28951
# [39]	validation_0-logloss:0.10797	validation_1-logloss:0.28751
# [40]	validation_0-logloss:0.10458	validation_1-logloss:0.28600
# [41]	validation_0-logloss:0.10116	validation_1-logloss:0.28381
# [42]	validation_0-logloss:0.09801	validation_1-logloss:0.28226
# [43]	validation_0-logloss:0.09494	validation_1-logloss:0.28086
# [44]	validation_0-logloss:0.09211	validation_1-logloss:0.27937
# [45]	validation_0-logloss:0.08939	validation_1-logloss:0.27746
# [46]	validation_0-logloss:0.08688	validation_1-logloss:0.27717
# [47]	validation_0-logloss:0.08441	validation_1-logloss:0.27523
# [48]	validation_0-logloss:0.08205	validation_1-logloss:0.27367
# [49]	validation_0-logloss:0.07981	validation_1-logloss:0.27254
# [50]	validation_0-logloss:0.07767	validation_1-logloss:0.27090
# [51]	validation_0-logloss:0.07565	validation_1-logloss:0.26996
# [52]	validation_0-logloss:0.07354	validation_1-logloss:0.26984
# [53]	validation_0-logloss:0.07169	validation_1-logloss:0.26846
# [54]	validation_0-logloss:0.06994	validation_1-logloss:0.26778
# [55]	validation_0-logloss:0.06822	validation_1-logloss:0.26653
# [56]	validation_0-logloss:0.06661	validation_1-logloss:0.26614
# [57]	validation_0-logloss:0.06509	validation_1-logloss:0.26509
# [58]	validation_0-logloss:0.06359	validation_1-logloss:0.26497
# [59]	validation_0-logloss:0.06218	validation_1-logloss:0.26424
# [60]	validation_0-logloss:0.06056	validation_1-logloss:0.26369
# [61]	validation_0-logloss:0.05909	validation_1-logloss:0.26197
# [62]	validation_0-logloss:0.05782	validation_1-logloss:0.26091
# [63]	validation_0-logloss:0.05648	validation_1-logloss:0.25936
# [64]	validation_0-logloss:0.05511	validation_1-logloss:0.25881
# [65]	validation_0-logloss:0.05383	validation_1-logloss:0.25837
# [66]	validation_0-logloss:0.05257	validation_1-logloss:0.25740
# [67]	validation_0-logloss:0.05132	validation_1-logloss:0.25701
# [68]	validation_0-logloss:0.05034	validation_1-logloss:0.25595
# [69]	validation_0-logloss:0.04901	validation_1-logloss:0.25522
# [70]	validation_0-logloss:0.04804	validation_1-logloss:0.25551
# [71]	validation_0-logloss:0.04702	validation_1-logloss:0.25487
# [72]	validation_0-logloss:0.04614	validation_1-logloss:0.25409
# [73]	validation_0-logloss:0.04518	validation_1-logloss:0.25447
# [74]	validation_0-logloss:0.04426	validation_1-logloss:0.25393
# [75]	validation_0-logloss:0.04337	validation_1-logloss:0.25386
# [76]	validation_0-logloss:0.04252	validation_1-logloss:0.25397
# [77]	validation_0-logloss:0.04168	validation_1-logloss:0.25278
# [78]	validation_0-logloss:0.04082	validation_1-logloss:0.25285
# [79]	validation_0-logloss:0.04005	validation_1-logloss:0.25188
# [80]	validation_0-logloss:0.03926	validation_1-logloss:0.25276
# [81]	validation_0-logloss:0.03849	validation_1-logloss:0.25294
# [82]	validation_0-logloss:0.03774	validation_1-logloss:0.25376
# [83]	validation_0-logloss:0.03712	validation_1-logloss:0.25441
# [84]	validation_0-logloss:0.03648	validation_1-logloss:0.25474
# [85]	validation_0-logloss:0.03578	validation_1-logloss:0.25497
# [86]	validation_0-logloss:0.03523	validation_1-logloss:0.25566
# [87]	validation_0-logloss:0.03458	validation_1-logloss:0.25602
# [88]	validation_0-logloss:0.03396	validation_1-logloss:0.25629
# 오차 행렬
# [[36  1]
#  [ 2 75]]
# 정확도: 0.9737, 정밀도: 0.9868, 재현율: 0.9740,    F1: 0.9804, AUC:0.9958

# %%
# Plotting important features
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

# fig:entire figure, ax:specific subplot(to pass as para)
fig, ax = plt.subplots(figsize=(10,12))
plot_importance(xgb_wrapper,ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %% [markdown]
# # LightGBM

# %%
# Importing lightgbm to check whether it works or not
import lightgbm
from lightgbm import LGBMClassifier

# %% [markdown]
# ## 사이킷런 래퍼 LightGBM 적용 - 위스콘신 유방암 예측

# %%
# Import
from lightgbm import LGBMClassifier
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# Load Dataset
dataset = load_breast_cancer()
# Change into dataframe
cancer_df = pd.DataFrame(data = dataset.data, columns=dataset.feature_names)
cancer_df['target'] = dataset.target

# Make Features & Label
X_features = cancer_df.iloc[:,:-1]
y_label = cancer_df.iloc[:,-1]

# Split dataset into Train & Test
X_train, X_test, y_train, y_test = train_test_split(X_features,y_label,test_size=0.2,random_state=156)

# Split Train data into Train & Validation
X_tr, X_val, y_tr, y_val = train_test_split(X_train,y_train,test_size=0.1,random_state=156)

# Make validation dataset
evals = [(X_tr,y_tr),(X_val,y_val)]
# Train
lgbm_wrapper = LGBMClassifier(n_estimators=400, learning_rate=0.05) #no max_depth
lgbm_wrapper.fit(X_tr,y_tr,eval_set=evals,verbose=True)
# Predict
pred = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:,1]
# Out:
# /opt/anaconda3/envs/파마완/lib/python3.8/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	training's binary_logloss: 0.625671	valid_1's binary_logloss: 0.628248
# [2]	training's binary_logloss: 0.588173	valid_1's binary_logloss: 0.601106
# [3]	training's binary_logloss: 0.554518	valid_1's binary_logloss: 0.577587
# [4]	training's binary_logloss: 0.523972	valid_1's binary_logloss: 0.556324
# [5]	training's binary_logloss: 0.49615	valid_1's binary_logloss: 0.537407
# [6]	training's binary_logloss: 0.470108	valid_1's binary_logloss: 0.519401
# [7]	training's binary_logloss: 0.446647	valid_1's binary_logloss: 0.502637
# [8]	training's binary_logloss: 0.425055	valid_1's binary_logloss: 0.488311
# [9]	training's binary_logloss: 0.405125	valid_1's binary_logloss: 0.474664
# [10]	training's binary_logloss: 0.386526	valid_1's binary_logloss: 0.461267
# [11]	training's binary_logloss: 0.367027	valid_1's binary_logloss: 0.444274
# [12]	training's binary_logloss: 0.350713	valid_1's binary_logloss: 0.432755
# [13]	training's binary_logloss: 0.334601	valid_1's binary_logloss: 0.421371
# [14]	training's binary_logloss: 0.319854	valid_1's binary_logloss: 0.411418
# [15]	training's binary_logloss: 0.306374	valid_1's binary_logloss: 0.402989
# [16]	training's binary_logloss: 0.293116	valid_1's binary_logloss: 0.393973
# [17]	training's binary_logloss: 0.280812	valid_1's binary_logloss: 0.384801
# [18]	training's binary_logloss: 0.268352	valid_1's binary_logloss: 0.376191
# [19]	training's binary_logloss: 0.256942	valid_1's binary_logloss: 0.368378
# [20]	training's binary_logloss: 0.246443	valid_1's binary_logloss: 0.362062
# [21]	training's binary_logloss: 0.236874	valid_1's binary_logloss: 0.355162
# [22]	training's binary_logloss: 0.227501	valid_1's binary_logloss: 0.348933
# [23]	training's binary_logloss: 0.218988	valid_1's binary_logloss: 0.342819
# [24]	training's binary_logloss: 0.210621	valid_1's binary_logloss: 0.337386
# [25]	training's binary_logloss: 0.202076	valid_1's binary_logloss: 0.331523
# [26]	training's binary_logloss: 0.194199	valid_1's binary_logloss: 0.326349
# [27]	training's binary_logloss: 0.187107	valid_1's binary_logloss: 0.322785
# [28]	training's binary_logloss: 0.180535	valid_1's binary_logloss: 0.317877
# [29]	training's binary_logloss: 0.173834	valid_1's binary_logloss: 0.313928
# [30]	training's binary_logloss: 0.167198	valid_1's binary_logloss: 0.310105
# [31]	training's binary_logloss: 0.161229	valid_1's binary_logloss: 0.307107
# [32]	training's binary_logloss: 0.155494	valid_1's binary_logloss: 0.303837
# [33]	training's binary_logloss: 0.149125	valid_1's binary_logloss: 0.300315
# [34]	training's binary_logloss: 0.144045	valid_1's binary_logloss: 0.297816
# [35]	training's binary_logloss: 0.139341	valid_1's binary_logloss: 0.295387
# [36]	training's binary_logloss: 0.134625	valid_1's binary_logloss: 0.293063
# [37]	training's binary_logloss: 0.129167	valid_1's binary_logloss: 0.289127
# [38]	training's binary_logloss: 0.12472	valid_1's binary_logloss: 0.288697
# [39]	training's binary_logloss: 0.11974	valid_1's binary_logloss: 0.28576
# [40]	training's binary_logloss: 0.115054	valid_1's binary_logloss: 0.282853
# [41]	training's binary_logloss: 0.110662	valid_1's binary_logloss: 0.279441
# [42]	training's binary_logloss: 0.106358	valid_1's binary_logloss: 0.28113
# [43]	training's binary_logloss: 0.102324	valid_1's binary_logloss: 0.279139
# [44]	training's binary_logloss: 0.0985699	valid_1's binary_logloss: 0.276465
# [45]	training's binary_logloss: 0.094858	valid_1's binary_logloss: 0.275946
# [46]	training's binary_logloss: 0.0912486	valid_1's binary_logloss: 0.272819
# [47]	training's binary_logloss: 0.0883115	valid_1's binary_logloss: 0.272306
# [48]	training's binary_logloss: 0.0849963	valid_1's binary_logloss: 0.270452
# [49]	training's binary_logloss: 0.0821742	valid_1's binary_logloss: 0.268671
# [50]	training's binary_logloss: 0.0789991	valid_1's binary_logloss: 0.267587
# [51]	training's binary_logloss: 0.0761072	valid_1's binary_logloss: 0.26626
# [52]	training's binary_logloss: 0.0732567	valid_1's binary_logloss: 0.265542
# [53]	training's binary_logloss: 0.0706388	valid_1's binary_logloss: 0.264547
# [54]	training's binary_logloss: 0.0683911	valid_1's binary_logloss: 0.26502
# [55]	training's binary_logloss: 0.0659347	valid_1's binary_logloss: 0.264388
# [56]	training's binary_logloss: 0.0636873	valid_1's binary_logloss: 0.263128
# [57]	training's binary_logloss: 0.0613354	valid_1's binary_logloss: 0.26231
# [58]	training's binary_logloss: 0.0591944	valid_1's binary_logloss: 0.262011
# [59]	training's binary_logloss: 0.057033	valid_1's binary_logloss: 0.261454
# [60]	training's binary_logloss: 0.0550801	valid_1's binary_logloss: 0.260746
# [61]	training's binary_logloss: 0.0532381	valid_1's binary_logloss: 0.260236
# [62]	training's binary_logloss: 0.0514074	valid_1's binary_logloss: 0.261586
# [63]	training's binary_logloss: 0.0494837	valid_1's binary_logloss: 0.261797
# [64]	training's binary_logloss: 0.0477826	valid_1's binary_logloss: 0.262533
# [65]	training's binary_logloss: 0.0460364	valid_1's binary_logloss: 0.263305
# [66]	training's binary_logloss: 0.0444552	valid_1's binary_logloss: 0.264072
# [67]	training's binary_logloss: 0.0427638	valid_1's binary_logloss: 0.266223
# [68]	training's binary_logloss: 0.0412449	valid_1's binary_logloss: 0.266817
# [69]	training's binary_logloss: 0.0398589	valid_1's binary_logloss: 0.267819
# [70]	training's binary_logloss: 0.0383095	valid_1's binary_logloss: 0.267484
# [71]	training's binary_logloss: 0.0368803	valid_1's binary_logloss: 0.270233
# [72]	training's binary_logloss: 0.0355637	valid_1's binary_logloss: 0.268442
# [73]	training's binary_logloss: 0.0341747	valid_1's binary_logloss: 0.26895
# [74]	training's binary_logloss: 0.0328302	valid_1's binary_logloss: 0.266958
# [75]	training's binary_logloss: 0.0317853	valid_1's binary_logloss: 0.268091
# [76]	training's binary_logloss: 0.0305626	valid_1's binary_logloss: 0.266419
# [77]	training's binary_logloss: 0.0295001	valid_1's binary_logloss: 0.268588
# [78]	training's binary_logloss: 0.0284699	valid_1's binary_logloss: 0.270964
# [79]	training's binary_logloss: 0.0273953	valid_1's binary_logloss: 0.270293
# [80]	training's binary_logloss: 0.0264668	valid_1's binary_logloss: 0.270523
# [81]	training's binary_logloss: 0.0254636	valid_1's binary_logloss: 0.270683
# [82]	training's binary_logloss: 0.0245911	valid_1's binary_logloss: 0.273187
# [83]	training's binary_logloss: 0.0236486	valid_1's binary_logloss: 0.275994
# [84]	training's binary_logloss: 0.0228047	valid_1's binary_logloss: 0.274053
# [85]	training's binary_logloss: 0.0221693	valid_1's binary_logloss: 0.273211
# [86]	training's binary_logloss: 0.0213043	valid_1's binary_logloss: 0.272626
# [87]	training's binary_logloss: 0.0203934	valid_1's binary_logloss: 0.27534
# [88]	training's binary_logloss: 0.0195552	valid_1's binary_logloss: 0.276228
# [89]	training's binary_logloss: 0.0188623	valid_1's binary_logloss: 0.27525
# [90]	training's binary_logloss: 0.0183664	valid_1's binary_logloss: 0.276485
# [91]	training's binary_logloss: 0.0176788	valid_1's binary_logloss: 0.277052
# [92]	training's binary_logloss: 0.0170059	valid_1's binary_logloss: 0.277686
# [93]	training's binary_logloss: 0.0164317	valid_1's binary_logloss: 0.275332
# [94]	training's binary_logloss: 0.015878	valid_1's binary_logloss: 0.276236
# [95]	training's binary_logloss: 0.0152959	valid_1's binary_logloss: 0.274538
# [96]	training's binary_logloss: 0.0147216	valid_1's binary_logloss: 0.275244
# [97]	training's binary_logloss: 0.0141758	valid_1's binary_logloss: 0.275829
# [98]	training's binary_logloss: 0.0136551	valid_1's binary_logloss: 0.276654
# [99]	training's binary_logloss: 0.0131585	valid_1's binary_logloss: 0.277859
# [100]	training's binary_logloss: 0.0126961	valid_1's binary_logloss: 0.279265
# [101]	training's binary_logloss: 0.0122421	valid_1's binary_logloss: 0.276695
# [102]	training's binary_logloss: 0.0118067	valid_1's binary_logloss: 0.278488
# [103]	training's binary_logloss: 0.0113994	valid_1's binary_logloss: 0.278932
# [104]	training's binary_logloss: 0.0109799	valid_1's binary_logloss: 0.280997
# [105]	training's binary_logloss: 0.0105953	valid_1's binary_logloss: 0.281454
# [106]	training's binary_logloss: 0.0102381	valid_1's binary_logloss: 0.282058
# [107]	training's binary_logloss: 0.00986714	valid_1's binary_logloss: 0.279275
# [108]	training's binary_logloss: 0.00950998	valid_1's binary_logloss: 0.281427
# [109]	training's binary_logloss: 0.00915965	valid_1's binary_logloss: 0.280752
# [110]	training's binary_logloss: 0.00882581	valid_1's binary_logloss: 0.282152
# [111]	training's binary_logloss: 0.00850714	valid_1's binary_logloss: 0.280894
# [112]	training's binary_logloss: 0.00821941	valid_1's binary_logloss: 0.280937
# [113]	training's binary_logloss: 0.00793986	valid_1's binary_logloss: 0.280883
# [114]	training's binary_logloss: 0.00765963	valid_1's binary_logloss: 0.28212
# [115]	training's binary_logloss: 0.00739843	valid_1's binary_logloss: 0.28209
# [116]	training's binary_logloss: 0.00713797	valid_1's binary_logloss: 0.281645
# [117]	training's binary_logloss: 0.00689175	valid_1's binary_logloss: 0.283368
# [118]	training's binary_logloss: 0.00666232	valid_1's binary_logloss: 0.283432
# [119]	training's binary_logloss: 0.00642551	valid_1's binary_logloss: 0.285776
# [120]	training's binary_logloss: 0.00620942	valid_1's binary_logloss: 0.286263
# [121]	training's binary_logloss: 0.00601358	valid_1's binary_logloss: 0.287199
# [122]	training's binary_logloss: 0.00581281	valid_1's binary_logloss: 0.289573
# [123]	training's binary_logloss: 0.0055841	valid_1's binary_logloss: 0.290346
# [124]	training's binary_logloss: 0.00538192	valid_1's binary_logloss: 0.289191
# [125]	training's binary_logloss: 0.00518299	valid_1's binary_logloss: 0.290637
# [126]	training's binary_logloss: 0.0049688	valid_1's binary_logloss: 0.292993
# [127]	training's binary_logloss: 0.00478966	valid_1's binary_logloss: 0.291903
# [128]	training's binary_logloss: 0.00463232	valid_1's binary_logloss: 0.292152
# [129]	training's binary_logloss: 0.00447864	valid_1's binary_logloss: 0.293925
# [130]	training's binary_logloss: 0.00431784	valid_1's binary_logloss: 0.297337
# [131]	training's binary_logloss: 0.00417038	valid_1's binary_logloss: 0.299738
# [132]	training's binary_logloss: 0.0040346	valid_1's binary_logloss: 0.301703
# [133]	training's binary_logloss: 0.00390103	valid_1's binary_logloss: 0.301485
# [134]	training's binary_logloss: 0.00375064	valid_1's binary_logloss: 0.302399
# [135]	training's binary_logloss: 0.00362923	valid_1's binary_logloss: 0.302673
# [136]	training's binary_logloss: 0.00347426	valid_1's binary_logloss: 0.30342
# [137]	training's binary_logloss: 0.00336164	valid_1's binary_logloss: 0.302697
# [138]	training's binary_logloss: 0.00323427	valid_1's binary_logloss: 0.303678
# [139]	training's binary_logloss: 0.00311391	valid_1's binary_logloss: 0.304723
# [140]	training's binary_logloss: 0.0030251	valid_1's binary_logloss: 0.305346
# [141]	training's binary_logloss: 0.00291992	valid_1's binary_logloss: 0.304978
# [142]	training's binary_logloss: 0.00282147	valid_1's binary_logloss: 0.305856
# [143]	training's binary_logloss: 0.00270196	valid_1's binary_logloss: 0.306666
# [144]	training's binary_logloss: 0.00259019	valid_1's binary_logloss: 0.306243
# [145]	training's binary_logloss: 0.00250659	valid_1's binary_logloss: 0.305652
# [146]	training's binary_logloss: 0.00240669	valid_1's binary_logloss: 0.305318
# [147]	training's binary_logloss: 0.00231155	valid_1's binary_logloss: 0.305046
# [148]	training's binary_logloss: 0.00223119	valid_1's binary_logloss: 0.304206
# [149]	training's binary_logloss: 0.00216957	valid_1's binary_logloss: 0.304814
# [150]	training's binary_logloss: 0.00210199	valid_1's binary_logloss: 0.304832
# [151]	training's binary_logloss: 0.00202444	valid_1's binary_logloss: 0.305803
# [152]	training's binary_logloss: 0.00196209	valid_1's binary_logloss: 0.305238
# [153]	training's binary_logloss: 0.00190114	valid_1's binary_logloss: 0.306796
# [154]	training's binary_logloss: 0.00182981	valid_1's binary_logloss: 0.304891
# [155]	training's binary_logloss: 0.00176246	valid_1's binary_logloss: 0.305923
# [156]	training's binary_logloss: 0.00169818	valid_1's binary_logloss: 0.304929
# [157]	training's binary_logloss: 0.00163272	valid_1's binary_logloss: 0.307516
# [158]	training's binary_logloss: 0.00157397	valid_1's binary_logloss: 0.306535
# [159]	training's binary_logloss: 0.00151902	valid_1's binary_logloss: 0.308453
# [160]	training's binary_logloss: 0.00147652	valid_1's binary_logloss: 0.309613
# [161]	training's binary_logloss: 0.00142899	valid_1's binary_logloss: 0.310951
# [162]	training's binary_logloss: 0.00138176	valid_1's binary_logloss: 0.313652
# [163]	training's binary_logloss: 0.00133334	valid_1's binary_logloss: 0.314928
# [164]	training's binary_logloss: 0.0012899	valid_1's binary_logloss: 0.314401
# [165]	training's binary_logloss: 0.00124115	valid_1's binary_logloss: 0.317039
# [166]	training's binary_logloss: 0.00118979	valid_1's binary_logloss: 0.318127
# [167]	training's binary_logloss: 0.00114732	valid_1's binary_logloss: 0.320124
# [168]	training's binary_logloss: 0.0011115	valid_1's binary_logloss: 0.321342
# [169]	training's binary_logloss: 0.00107767	valid_1's binary_logloss: 0.322127
# [170]	training's binary_logloss: 0.00104028	valid_1's binary_logloss: 0.324816
# [171]	training's binary_logloss: 0.00100232	valid_1's binary_logloss: 0.325902
# [172]	training's binary_logloss: 0.000965666	valid_1's binary_logloss: 0.327888
# [173]	training's binary_logloss: 0.000931626	valid_1's binary_logloss: 0.329977
# [174]	training's binary_logloss: 0.000902107	valid_1's binary_logloss: 0.331152
# [175]	training's binary_logloss: 0.000875996	valid_1's binary_logloss: 0.33387
# [176]	training's binary_logloss: 0.000844632	valid_1's binary_logloss: 0.334551
# [177]	training's binary_logloss: 0.000815782	valid_1's binary_logloss: 0.334669
# [178]	training's binary_logloss: 0.00078864	valid_1's binary_logloss: 0.335875
# [179]	training's binary_logloss: 0.000765142	valid_1's binary_logloss: 0.336024
# [180]	training's binary_logloss: 0.000740035	valid_1's binary_logloss: 0.338678
# [181]	training's binary_logloss: 0.000715512	valid_1's binary_logloss: 0.341509
# [182]	training's binary_logloss: 0.000691303	valid_1's binary_logloss: 0.342421
# [183]	training's binary_logloss: 0.000667086	valid_1's binary_logloss: 0.34225
# [184]	training's binary_logloss: 0.000642643	valid_1's binary_logloss: 0.342181
# [185]	training's binary_logloss: 0.000619614	valid_1's binary_logloss: 0.343669
# [186]	training's binary_logloss: 0.000597685	valid_1's binary_logloss: 0.343493
# [187]	training's binary_logloss: 0.00057594	valid_1's binary_logloss: 0.344934
# [188]	training's binary_logloss: 0.000554597	valid_1's binary_logloss: 0.348261
# [189]	training's binary_logloss: 0.000536574	valid_1's binary_logloss: 0.34769
# [190]	training's binary_logloss: 0.000517746	valid_1's binary_logloss: 0.347245
# [191]	training's binary_logloss: 0.000499107	valid_1's binary_logloss: 0.349328
# [192]	training's binary_logloss: 0.000479643	valid_1's binary_logloss: 0.34957
# [193]	training's binary_logloss: 0.000464697	valid_1's binary_logloss: 0.349098
# [194]	training's binary_logloss: 0.00044823	valid_1's binary_logloss: 0.350479
# [195]	training's binary_logloss: 0.000432085	valid_1's binary_logloss: 0.352131
# [196]	training's binary_logloss: 0.000415281	valid_1's binary_logloss: 0.352377
# [197]	training's binary_logloss: 0.000399144	valid_1's binary_logloss: 0.354924
# [198]	training's binary_logloss: 0.000385647	valid_1's binary_logloss: 0.354495
# [199]	training's binary_logloss: 0.000369239	valid_1's binary_logloss: 0.355602
# [200]	training's binary_logloss: 0.000356556	valid_1's binary_logloss: 0.357264
# [201]	training's binary_logloss: 0.000344026	valid_1's binary_logloss: 0.356634
# [202]	training's binary_logloss: 0.000333081	valid_1's binary_logloss: 0.359739
# [203]	training's binary_logloss: 0.000321406	valid_1's binary_logloss: 0.361248
# [204]	training's binary_logloss: 0.00031018	valid_1's binary_logloss: 0.362224
# [205]	training's binary_logloss: 0.000300254	valid_1's binary_logloss: 0.363611
# [206]	training's binary_logloss: 0.000288621	valid_1's binary_logloss: 0.363796
# [207]	training's binary_logloss: 0.000277252	valid_1's binary_logloss: 0.366621
# [208]	training's binary_logloss: 0.000265669	valid_1's binary_logloss: 0.367678
# [209]	training's binary_logloss: 0.000258026	valid_1's binary_logloss: 0.370367
# [210]	training's binary_logloss: 0.000249173	valid_1's binary_logloss: 0.370987
# [211]	training's binary_logloss: 0.000238875	valid_1's binary_logloss: 0.372204
# [212]	training's binary_logloss: 0.00022911	valid_1's binary_logloss: 0.373465
# [213]	training's binary_logloss: 0.000221918	valid_1's binary_logloss: 0.373934
# [214]	training's binary_logloss: 0.000214237	valid_1's binary_logloss: 0.375767
# [215]	training's binary_logloss: 0.000206482	valid_1's binary_logloss: 0.376784
# [216]	training's binary_logloss: 0.000199671	valid_1's binary_logloss: 0.378745
# [217]	training's binary_logloss: 0.000193243	valid_1's binary_logloss: 0.378859
# [218]	training's binary_logloss: 0.000187022	valid_1's binary_logloss: 0.380806
# [219]	training's binary_logloss: 0.000180526	valid_1's binary_logloss: 0.382457
# [220]	training's binary_logloss: 0.000173532	valid_1's binary_logloss: 0.382938
# [221]	training's binary_logloss: 0.00016695	valid_1's binary_logloss: 0.383907
# [222]	training's binary_logloss: 0.000162252	valid_1's binary_logloss: 0.38671
# [223]	training's binary_logloss: 0.000157059	valid_1's binary_logloss: 0.388622
# [224]	training's binary_logloss: 0.000151149	valid_1's binary_logloss: 0.389127
# [225]	training's binary_logloss: 0.00014637	valid_1's binary_logloss: 0.389362
# [226]	training's binary_logloss: 0.000141758	valid_1's binary_logloss: 0.391221
# [227]	training's binary_logloss: 0.000137617	valid_1's binary_logloss: 0.391495
# [228]	training's binary_logloss: 0.000133006	valid_1's binary_logloss: 0.393201
# [229]	training's binary_logloss: 0.00012903	valid_1's binary_logloss: 0.393677
# [230]	training's binary_logloss: 0.000123708	valid_1's binary_logloss: 0.395356
# [231]	training's binary_logloss: 0.0001196	valid_1's binary_logloss: 0.397037
# [232]	training's binary_logloss: 0.000115692	valid_1's binary_logloss: 0.399997
# [233]	training's binary_logloss: 0.000111775	valid_1's binary_logloss: 0.40101
# [234]	training's binary_logloss: 0.000108639	valid_1's binary_logloss: 0.401594
# [235]	training's binary_logloss: 0.000104793	valid_1's binary_logloss: 0.402652
# [236]	training's binary_logloss: 0.000100941	valid_1's binary_logloss: 0.402851
# [237]	training's binary_logloss: 9.75814e-05	valid_1's binary_logloss: 0.403845
# [238]	training's binary_logloss: 9.39573e-05	valid_1's binary_logloss: 0.404532
# [239]	training's binary_logloss: 9.06691e-05	valid_1's binary_logloss: 0.405664
# [240]	training's binary_logloss: 8.81794e-05	valid_1's binary_logloss: 0.40851
# [241]	training's binary_logloss: 8.50782e-05	valid_1's binary_logloss: 0.408079
# [242]	training's binary_logloss: 8.19778e-05	valid_1's binary_logloss: 0.408371
# [243]	training's binary_logloss: 7.9552e-05	valid_1's binary_logloss: 0.410765
# [244]	training's binary_logloss: 7.7069e-05	valid_1's binary_logloss: 0.410285
# [245]	training's binary_logloss: 7.45398e-05	valid_1's binary_logloss: 0.411556
# [246]	training's binary_logloss: 7.2395e-05	valid_1's binary_logloss: 0.414231
# [247]	training's binary_logloss: 6.95265e-05	valid_1's binary_logloss: 0.417119
# [248]	training's binary_logloss: 6.72395e-05	valid_1's binary_logloss: 0.418176
# [249]	training's binary_logloss: 6.53746e-05	valid_1's binary_logloss: 0.421031
# [250]	training's binary_logloss: 6.36797e-05	valid_1's binary_logloss: 0.421947
# [251]	training's binary_logloss: 6.16943e-05	valid_1's binary_logloss: 0.423532
# [252]	training's binary_logloss: 5.9867e-05	valid_1's binary_logloss: 0.424371
# [253]	training's binary_logloss: 5.78992e-05	valid_1's binary_logloss: 0.42478
# [254]	training's binary_logloss: 5.55902e-05	valid_1's binary_logloss: 0.426336
# [255]	training's binary_logloss: 5.40129e-05	valid_1's binary_logloss: 0.4277
# [256]	training's binary_logloss: 5.22739e-05	valid_1's binary_logloss: 0.430654
# [257]	training's binary_logloss: 5.06601e-05	valid_1's binary_logloss: 0.430851
# [258]	training's binary_logloss: 4.87848e-05	valid_1's binary_logloss: 0.433784
# [259]	training's binary_logloss: 4.73085e-05	valid_1's binary_logloss: 0.43397
# [260]	training's binary_logloss: 4.58649e-05	valid_1's binary_logloss: 0.436519
# [261]	training's binary_logloss: 4.45456e-05	valid_1's binary_logloss: 0.437256
# [262]	training's binary_logloss: 4.32289e-05	valid_1's binary_logloss: 0.437497
# [263]	training's binary_logloss: 4.19443e-05	valid_1's binary_logloss: 0.439193
# [264]	training's binary_logloss: 4.0613e-05	valid_1's binary_logloss: 0.440604
# [265]	training's binary_logloss: 3.92537e-05	valid_1's binary_logloss: 0.44343
# [266]	training's binary_logloss: 3.79059e-05	valid_1's binary_logloss: 0.444462
# [267]	training's binary_logloss: 3.66851e-05	valid_1's binary_logloss: 0.445572
# [268]	training's binary_logloss: 3.55786e-05	valid_1's binary_logloss: 0.4458
# [269]	training's binary_logloss: 3.44801e-05	valid_1's binary_logloss: 0.447052
# [270]	training's binary_logloss: 3.35406e-05	valid_1's binary_logloss: 0.449009
# [271]	training's binary_logloss: 3.24715e-05	valid_1's binary_logloss: 0.450237
# [272]	training's binary_logloss: 3.14198e-05	valid_1's binary_logloss: 0.449732
# [273]	training's binary_logloss: 3.03911e-05	valid_1's binary_logloss: 0.452554
# [274]	training's binary_logloss: 2.96408e-05	valid_1's binary_logloss: 0.454676
# [275]	training's binary_logloss: 2.86784e-05	valid_1's binary_logloss: 0.453344
# [276]	training's binary_logloss: 2.79344e-05	valid_1's binary_logloss: 0.454841
# [277]	training's binary_logloss: 2.7145e-05	valid_1's binary_logloss: 0.457655
# [278]	training's binary_logloss: 2.64182e-05	valid_1's binary_logloss: 0.459409
# [279]	training's binary_logloss: 2.56504e-05	valid_1's binary_logloss: 0.460738
# [280]	training's binary_logloss: 2.49849e-05	valid_1's binary_logloss: 0.461748
# [281]	training's binary_logloss: 2.41833e-05	valid_1's binary_logloss: 0.462366
# [282]	training's binary_logloss: 2.36711e-05	valid_1's binary_logloss: 0.462144
# [283]	training's binary_logloss: 2.30898e-05	valid_1's binary_logloss: 0.46238
# [284]	training's binary_logloss: 2.24393e-05	valid_1's binary_logloss: 0.463793
# [285]	training's binary_logloss: 2.18583e-05	valid_1's binary_logloss: 0.464839
# [286]	training's binary_logloss: 2.12995e-05	valid_1's binary_logloss: 0.464616
# [287]	training's binary_logloss: 2.07644e-05	valid_1's binary_logloss: 0.464706
# [288]	training's binary_logloss: 2.03305e-05	valid_1's binary_logloss: 0.465367
# [289]	training's binary_logloss: 1.98757e-05	valid_1's binary_logloss: 0.464141
# [290]	training's binary_logloss: 1.94858e-05	valid_1's binary_logloss: 0.463974
# [291]	training's binary_logloss: 1.89719e-05	valid_1's binary_logloss: 0.46621
# [292]	training's binary_logloss: 1.85795e-05	valid_1's binary_logloss: 0.467011
# [293]	training's binary_logloss: 1.81737e-05	valid_1's binary_logloss: 0.46642
# [294]	training's binary_logloss: 1.78111e-05	valid_1's binary_logloss: 0.467221
# [295]	training's binary_logloss: 1.7466e-05	valid_1's binary_logloss: 0.466086
# [296]	training's binary_logloss: 1.69697e-05	valid_1's binary_logloss: 0.467644
# [297]	training's binary_logloss: 1.66027e-05	valid_1's binary_logloss: 0.469196
# [298]	training's binary_logloss: 1.62344e-05	valid_1's binary_logloss: 0.471175
# [299]	training's binary_logloss: 1.58977e-05	valid_1's binary_logloss: 0.472711
# [300]	training's binary_logloss: 1.56572e-05	valid_1's binary_logloss: 0.473157
# [301]	training's binary_logloss: 1.53347e-05	valid_1's binary_logloss: 0.473787
# [302]	training's binary_logloss: 1.50537e-05	valid_1's binary_logloss: 0.475282
# [303]	training's binary_logloss: 1.4797e-05	valid_1's binary_logloss: 0.474848
# [304]	training's binary_logloss: 1.45737e-05	valid_1's binary_logloss: 0.474208
# [305]	training's binary_logloss: 1.4303e-05	valid_1's binary_logloss: 0.475267
# [306]	training's binary_logloss: 1.40478e-05	valid_1's binary_logloss: 0.476077
# [307]	training's binary_logloss: 1.37887e-05	valid_1's binary_logloss: 0.474949
# [308]	training's binary_logloss: 1.35731e-05	valid_1's binary_logloss: 0.476646
# [309]	training's binary_logloss: 1.33843e-05	valid_1's binary_logloss: 0.478045
# [310]	training's binary_logloss: 1.31983e-05	valid_1's binary_logloss: 0.479339
# [311]	training's binary_logloss: 1.30273e-05	valid_1's binary_logloss: 0.480709
# [312]	training's binary_logloss: 1.2858e-05	valid_1's binary_logloss: 0.482038
# [313]	training's binary_logloss: 1.26727e-05	valid_1's binary_logloss: 0.481268
# [314]	training's binary_logloss: 1.25603e-05	valid_1's binary_logloss: 0.482193
# [315]	training's binary_logloss: 1.24086e-05	valid_1's binary_logloss: 0.483414
# [316]	training's binary_logloss: 1.23034e-05	valid_1's binary_logloss: 0.484322
# [317]	training's binary_logloss: 1.21617e-05	valid_1's binary_logloss: 0.485516
# [318]	training's binary_logloss: 1.20631e-05	valid_1's binary_logloss: 0.486409
# [319]	training's binary_logloss: 1.19629e-05	valid_1's binary_logloss: 0.487611
# [320]	training's binary_logloss: 1.18318e-05	valid_1's binary_logloss: 0.488551
# [321]	training's binary_logloss: 1.16134e-05	valid_1's binary_logloss: 0.489263
# [322]	training's binary_logloss: 1.15217e-05	valid_1's binary_logloss: 0.490147
# [323]	training's binary_logloss: 1.14211e-05	valid_1's binary_logloss: 0.491007
# [324]	training's binary_logloss: 1.12694e-05	valid_1's binary_logloss: 0.490935
# [325]	training's binary_logloss: 1.11772e-05	valid_1's binary_logloss: 0.492143
# [326]	training's binary_logloss: 1.09809e-05	valid_1's binary_logloss: 0.492856
# [327]	training's binary_logloss: 1.08426e-05	valid_1's binary_logloss: 0.492824
# [328]	training's binary_logloss: 1.07601e-05	valid_1's binary_logloss: 0.494039
# [329]	training's binary_logloss: 1.06176e-05	valid_1's binary_logloss: 0.494456
# [330]	training's binary_logloss: 1.05187e-05	valid_1's binary_logloss: 0.494352
# [331]	training's binary_logloss: 1.04009e-05	valid_1's binary_logloss: 0.494414
# [332]	training's binary_logloss: 1.02838e-05	valid_1's binary_logloss: 0.494424
# [333]	training's binary_logloss: 1.01801e-05	valid_1's binary_logloss: 0.494212
# [334]	training's binary_logloss: 1.01031e-05	valid_1's binary_logloss: 0.495058
# [335]	training's binary_logloss: 1.00297e-05	valid_1's binary_logloss: 0.495404
# [336]	training's binary_logloss: 9.94596e-06	valid_1's binary_logloss: 0.496067
# [337]	training's binary_logloss: 9.88976e-06	valid_1's binary_logloss: 0.495684
# [338]	training's binary_logloss: 9.81755e-06	valid_1's binary_logloss: 0.496518
# [339]	training's binary_logloss: 9.74977e-06	valid_1's binary_logloss: 0.496869
# [340]	training's binary_logloss: 9.68325e-06	valid_1's binary_logloss: 0.497118
# [341]	training's binary_logloss: 9.63386e-06	valid_1's binary_logloss: 0.496137
# [342]	training's binary_logloss: 9.57062e-06	valid_1's binary_logloss: 0.496487
# [343]	training's binary_logloss: 9.49715e-06	valid_1's binary_logloss: 0.496483
# [344]	training's binary_logloss: 9.44911e-06	valid_1's binary_logloss: 0.495502
# [345]	training's binary_logloss: 9.3724e-06	valid_1's binary_logloss: 0.496137
# [346]	training's binary_logloss: 9.29176e-06	valid_1's binary_logloss: 0.495428
# [347]	training's binary_logloss: 9.22845e-06	valid_1's binary_logloss: 0.494964
# [348]	training's binary_logloss: 9.14871e-06	valid_1's binary_logloss: 0.493817
# [349]	training's binary_logloss: 9.0986e-06	valid_1's binary_logloss: 0.494802
# [350]	training's binary_logloss: 9.07094e-06	valid_1's binary_logloss: 0.494655
# [351]	training's binary_logloss: 9.02441e-06	valid_1's binary_logloss: 0.495619
# [352]	training's binary_logloss: 8.99812e-06	valid_1's binary_logloss: 0.495239
# [353]	training's binary_logloss: 8.92949e-06	valid_1's binary_logloss: 0.494542
# [354]	training's binary_logloss: 8.85666e-06	valid_1's binary_logloss: 0.493879
# [355]	training's binary_logloss: 8.78395e-06	valid_1's binary_logloss: 0.492775
# [356]	training's binary_logloss: 8.72634e-06	valid_1's binary_logloss: 0.49235
# [357]	training's binary_logloss: 8.67976e-06	valid_1's binary_logloss: 0.493325
# [358]	training's binary_logloss: 8.62168e-06	valid_1's binary_logloss: 0.492275
# [359]	training's binary_logloss: 8.55312e-06	valid_1's binary_logloss: 0.493403
# [360]	training's binary_logloss: 8.528e-06	valid_1's binary_logloss: 0.493224
# [361]	training's binary_logloss: 8.48524e-06	valid_1's binary_logloss: 0.494185
# [362]	training's binary_logloss: 8.46106e-06	valid_1's binary_logloss: 0.494043
# [363]	training's binary_logloss: 8.42292e-06	valid_1's binary_logloss: 0.494553
# [364]	training's binary_logloss: 8.35471e-06	valid_1's binary_logloss: 0.494082
# [365]	training's binary_logloss: 8.28795e-06	valid_1's binary_logloss: 0.492981
# [366]	training's binary_logloss: 8.23703e-06	valid_1's binary_logloss: 0.492459
# [367]	training's binary_logloss: 8.1742e-06	valid_1's binary_logloss: 0.491619
# [368]	training's binary_logloss: 8.12578e-06	valid_1's binary_logloss: 0.490627
# [369]	training's binary_logloss: 8.05709e-06	valid_1's binary_logloss: 0.490557
# [370]	training's binary_logloss: 8.02296e-06	valid_1's binary_logloss: 0.491449
# [371]	training's binary_logloss: 7.96221e-06	valid_1's binary_logloss: 0.49253
# [372]	training's binary_logloss: 7.91391e-06	valid_1's binary_logloss: 0.492039
# [373]	training's binary_logloss: 7.89315e-06	valid_1's binary_logloss: 0.491873
# [374]	training's binary_logloss: 7.87197e-06	valid_1's binary_logloss: 0.492658
# [375]	training's binary_logloss: 7.83638e-06	valid_1's binary_logloss: 0.491786
# [376]	training's binary_logloss: 7.77334e-06	valid_1's binary_logloss: 0.491723
# [377]	training's binary_logloss: 7.72342e-06	valid_1's binary_logloss: 0.492306
# [378]	training's binary_logloss: 7.70331e-06	valid_1's binary_logloss: 0.493039
# [379]	training's binary_logloss: 7.68343e-06	valid_1's binary_logloss: 0.493256
# [380]	training's binary_logloss: 7.66356e-06	valid_1's binary_logloss: 0.492896
# [381]	training's binary_logloss: 7.64363e-06	valid_1's binary_logloss: 0.493671
# [382]	training's binary_logloss: 7.61125e-06	valid_1's binary_logloss: 0.493333
# [383]	training's binary_logloss: 7.59222e-06	valid_1's binary_logloss: 0.493391
# [384]	training's binary_logloss: 7.57316e-06	valid_1's binary_logloss: 0.494154
# [385]	training's binary_logloss: 7.55379e-06	valid_1's binary_logloss: 0.493795
# [386]	training's binary_logloss: 7.53498e-06	valid_1's binary_logloss: 0.494009
# [387]	training's binary_logloss: 7.49517e-06	valid_1's binary_logloss: 0.495226
# [388]	training's binary_logloss: 7.46997e-06	valid_1's binary_logloss: 0.494419
# [389]	training's binary_logloss: 7.45166e-06	valid_1's binary_logloss: 0.493854
# [390]	training's binary_logloss: 7.43388e-06	valid_1's binary_logloss: 0.494597
# [391]	training's binary_logloss: 7.41549e-06	valid_1's binary_logloss: 0.494657
# [392]	training's binary_logloss: 7.39732e-06	valid_1's binary_logloss: 0.493867
# [393]	training's binary_logloss: 7.36069e-06	valid_1's binary_logloss: 0.493803
# [394]	training's binary_logloss: 7.34328e-06	valid_1's binary_logloss: 0.493459
# [395]	training's binary_logloss: 7.32575e-06	valid_1's binary_logloss: 0.494201
# [396]	training's binary_logloss: 7.30803e-06	valid_1's binary_logloss: 0.493802
# [397]	training's binary_logloss: 7.29065e-06	valid_1's binary_logloss: 0.493251
# [398]	training's binary_logloss: 7.27372e-06	valid_1's binary_logloss: 0.493308
# [399]	training's binary_logloss: 7.25642e-06	valid_1's binary_logloss: 0.494052
# [400]	training's binary_logloss: 7.23907e-06	valid_1's binary_logloss: 0.493603

# %%
# Evaluate
get_clf_eval(y_test,pred,pred_proba)
# Out:
# 오차 행렬
# [[34  3]
#  [ 2 75]]
# 정확도: 0.9561, 정밀도: 0.9615, 재현율: 0.9740,    F1: 0.9677, AUC:0.9923

# %%
# Plotting important features
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgbm_wrapper, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# # 베이지안 최적화 기반의 HyperOpt를 이용한 하이퍼 파라미터 튜닝

# %% [markdown]
# ## HyperOpt 활용

# %%
from hyperopt import hp

# Setting Search Space
# x: -10,-9,-8...,10 / y: -15,-14,...,15
search_space = {'x': hp.quniform('x', -10, 10, 1), 'y': hp.quniform('y', -15, 15, 1) }

# %%
# Objective function
from hyperopt import STATUS_OK

def objective_func(search_space):
    x = search_space['x']
    y = search_space['y']
    retval = x**2 - 20*y
    
    return retval

# %%
# Finding most optimized input value 
# max_evals : 5
from hyperopt import fmin, tpe, Trials
import numpy as np

trial_val = Trials()

best_01 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=5
               , trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_01)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 460.28trial/s, best loss: -224.0]
# best: {'x': -4.0, 'y': 12.0}

# %%
# Increasing max_evals to 20
trial_val = Trials()

# max_evals를 20회로 늘려서 재테스트
best_02 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=20
               , trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_02)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 1675.61trial/s, best loss: -296.0]
# best: {'x': 2.0, 'y': 15.0}

# %%
# Print results
print(trial_val.results)
# Out:
# [{'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -296.0, 'status': 'ok'}, {'loss': -40.0, 'status': 'ok'}, {'loss': 281.0, 'status': 'ok'}, {'loss': 64.0, 'status': 'ok'}, {'loss': 100.0, 'status': 'ok'}, {'loss': 60.0, 'status': 'ok'}, {'loss': -39.0, 'status': 'ok'}, {'loss': 1.0, 'status': 'ok'}, {'loss': -164.0, 'status': 'ok'}, {'loss': 21.0, 'status': 'ok'}, {'loss': -56.0, 'status': 'ok'}, {'loss': 284.0, 'status': 'ok'}, {'loss': 176.0, 'status': 'ok'}, {'loss': -171.0, 'status': 'ok'}, {'loss': 0.0, 'status': 'ok'}]

# %%
# Print vals
print(trial_val.vals)
# Out:
# {'x': [-6.0, -4.0, 4.0, -4.0, 9.0, 2.0, 10.0, -9.0, -8.0, -0.0, -0.0, 1.0, 9.0, 6.0, 9.0, 2.0, -2.0, -4.0, 7.0, -0.0], 'y': [5.0, 10.0, -2.0, 12.0, 1.0, 15.0, 7.0, -10.0, 0.0, -5.0, -3.0, 2.0, 4.0, 10.0, 3.0, 3.0, -14.0, -8.0, 11.0, -0.0]}

# %%
# Visualization as DataFrame
import pandas as pd

losses = [loss_dict['loss'] for loss_dict in trial_val.results]

result_df = pd.DataFrame({'x': trial_val.vals['x'], 'y': trial_val.vals['y'], 'losses': losses})
result_df.head()
# Out:
#      x     y  losses
# 0 -6.0   5.0   -64.0
# 1 -4.0  10.0  -184.0
# 2  4.0  -2.0    56.0
# 3 -4.0  12.0  -224.0
# 4  9.0   1.0    61.0

# %% [markdown]
# ## HyperOpt를 이용한 XGBoost 하이퍼 파라미터 최적화

# %%
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156 )

X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156 )

# %%
# Setting Search Space
xgb_search_space = {'max_depth': hp.quniform('max_depth', 5, 20, 1), 
                    'min_child_weight': hp.quniform('min_child_weight', 1, 2, 1),
                    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
                    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
                   }

# %%
# Objective Function
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

def objective_func(search_space):
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            learning_rate=search_space['learning_rate'],
                            colsample_bytree=search_space['colsample_bytree'],
                            eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)
    
    return {'loss':-1 * np.mean(accuracy), 'status': STATUS_OK}

# %%
# Finding most optimized input value 
from hyperopt import fmin, tpe, Trials

trial_val = Trials()
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=50, 
            trials=trial_val, rstate=np.random.default_rng(seed=9))
print('best:', best)
# Out:
# 100%|██████████| 50/50 [00:05<00:00,  9.21trial/s, best loss: -0.9692401533635412]
# best: {'colsample_bytree': 0.548301545497125, 'learning_rate': 0.1840281762576621, 'max_depth': 18.0, 'min_child_weight': 2.0}

# %%
print('colsample_bytree:{0}, learning_rate:{1}, max_depth:{2}, min_child_weight:{3}'.format(
    round(best['colsample_bytree'], 5), round(best['learning_rate'], 5),
    int(best['max_depth']), int(best['min_child_weight'])))
# Out:
# colsample_bytree:0.5483, learning_rate:0.18403, max_depth:18, min_child_weight:2

# %%
# Re-Train with extracted hyper parameters
xgb_wrapper = XGBClassifier(n_estimators=400,
                            learning_rate=round(best['learning_rate'], 5),
                            max_depth=int(best['max_depth']),
                            min_child_weight=int(best['min_child_weight']),
                            colsample_bytree=round(best['colsample_bytree'], 5)
                           )

evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric='logloss',
                eval_set=evals, verbose=True)

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, preds, pred_proba)
# Out:
# [0]	validation_0-logloss:0.54472	validation_1-logloss:0.58675
# [1]	validation_0-logloss:0.44155	validation_1-logloss:0.52577
# [2]	validation_0-logloss:0.36542	validation_1-logloss:0.48906
# [3]	validation_0-logloss:0.30756	validation_1-logloss:0.45704
# [4]	validation_0-logloss:0.26142	validation_1-logloss:0.41671
# [5]	validation_0-logloss:0.22616	validation_1-logloss:0.39605
# [6]	validation_0-logloss:0.19465	validation_1-logloss:0.37095
# [7]	validation_0-logloss:0.16951	validation_1-logloss:0.36066
# [8]	validation_0-logloss:0.14718	validation_1-logloss:0.34686
# [9]	validation_0-logloss:0.13006	validation_1-logloss:0.33716
# [10]	validation_0-logloss:0.11635	validation_1-logloss:0.32332
# [11]	validation_0-logloss:0.10455	validation_1-logloss:0.32073
# [12]	validation_0-logloss:0.09388	validation_1-logloss:0.31916
# [13]	validation_0-logloss:0.08434	validation_1-logloss:0.30988
# [14]	validation_0-logloss:0.07702	validation_1-logloss:0.30469
# [15]	validation_0-logloss:0.07144	validation_1-logloss:0.30293
# [16]	validation_0-logloss:0.06649	validation_1-logloss:0.29609
# [17]	validation_0-logloss:0.06119	validation_1-logloss:0.29303
# [18]	validation_0-logloss:0.05693	validation_1-logloss:0.28973
# [19]	validation_0-logloss:0.05291	validation_1-logloss:0.28781
# [20]	validation_0-logloss:0.04951	validation_1-logloss:0.28757
# [21]	validation_0-logloss:0.04603	validation_1-logloss:0.28904
# [22]	validation_0-logloss:0.04376	validation_1-logloss:0.28744
# [23]	validation_0-logloss:0.04113	validation_1-logloss:0.29028
# [24]	validation_0-logloss:0.03932	validation_1-logloss:0.28659
# [25]	validation_0-logloss:0.03741	validation_1-logloss:0.29059
# [26]	validation_0-logloss:0.03570	validation_1-logloss:0.28740
# [27]	validation_0-logloss:0.03416	validation_1-logloss:0.28613
# [28]	validation_0-logloss:0.03309	validation_1-logloss:0.28441
# [29]	validation_0-logloss:0.03166	validation_1-logloss:0.28617
# [30]	validation_0-logloss:0.03059	validation_1-logloss:0.28501
# [31]	validation_0-logloss:0.02961	validation_1-logloss:0.28505
# [32]	validation_0-logloss:0.02881	validation_1-logloss:0.28319
# [33]	validation_0-logloss:0.02801	validation_1-logloss:0.28407
# [34]	validation_0-logloss:0.02710	validation_1-logloss:0.27684
# [35]	validation_0-logloss:0.02654	validation_1-logloss:0.27598
# [36]	validation_0-logloss:0.02591	validation_1-logloss:0.27329
# [37]	validation_0-logloss:0.02514	validation_1-logloss:0.26722
# [38]	validation_0-logloss:0.02484	validation_1-logloss:0.26668
# [39]	validation_0-logloss:0.02424	validation_1-logloss:0.26733
# [40]	validation_0-logloss:0.02404	validation_1-logloss:0.26721
# [41]	validation_0-logloss:0.02374	validation_1-logloss:0.26519
# [42]	validation_0-logloss:0.02351	validation_1-logloss:0.26809
# [43]	validation_0-logloss:0.02295	validation_1-logloss:0.27016
# [44]	validation_0-logloss:0.02272	validation_1-logloss:0.26844
# [45]	validation_0-logloss:0.02252	validation_1-logloss:0.27126
# [46]	validation_0-logloss:0.02233	validation_1-logloss:0.26975
# [47]	validation_0-logloss:0.02214	validation_1-logloss:0.26975
# [48]	validation_0-logloss:0.02175	validation_1-logloss:0.27071
# [49]	validation_0-logloss:0.02157	validation_1-logloss:0.26926
# [50]	validation_0-logloss:0.02122	validation_1-logloss:0.27124
# [51]	validation_0-logloss:0.02087	validation_1-logloss:0.27159
# [52]	validation_0-logloss:0.02070	validation_1-logloss:0.27435
# [53]	validation_0-logloss:0.02054	validation_1-logloss:0.27227
# [54]	validation_0-logloss:0.02040	validation_1-logloss:0.27114
# [55]	validation_0-logloss:0.02025	validation_1-logloss:0.26898
# [56]	validation_0-logloss:0.02012	validation_1-logloss:0.27039
# [57]	validation_0-logloss:0.01998	validation_1-logloss:0.26914
# [58]	validation_0-logloss:0.01983	validation_1-logloss:0.27181
# [59]	validation_0-logloss:0.01970	validation_1-logloss:0.27142
# [60]	validation_0-logloss:0.01956	validation_1-logloss:0.26793
# [61]	validation_0-logloss:0.01945	validation_1-logloss:0.26890
# [62]	validation_0-logloss:0.01932	validation_1-logloss:0.26558
# [63]	validation_0-logloss:0.01922	validation_1-logloss:0.26380
# [64]	validation_0-logloss:0.01909	validation_1-logloss:0.26627
# [65]	validation_0-logloss:0.01896	validation_1-logloss:0.26761
# [66]	validation_0-logloss:0.01885	validation_1-logloss:0.26726
# [67]	validation_0-logloss:0.01874	validation_1-logloss:0.26420
# [68]	validation_0-logloss:0.01863	validation_1-logloss:0.26519
# [69]	validation_0-logloss:0.01852	validation_1-logloss:0.26755
# [70]	validation_0-logloss:0.01841	validation_1-logloss:0.26766
# [71]	validation_0-logloss:0.01831	validation_1-logloss:0.26738
# [72]	validation_0-logloss:0.01821	validation_1-logloss:0.26560
# [73]	validation_0-logloss:0.01811	validation_1-logloss:0.26778
# [74]	validation_0-logloss:0.01802	validation_1-logloss:0.26628
# [75]	validation_0-logloss:0.01792	validation_1-logloss:0.26601
# [76]	validation_0-logloss:0.01782	validation_1-logloss:0.26490
# [77]	validation_0-logloss:0.01773	validation_1-logloss:0.26706
# [78]	validation_0-logloss:0.01764	validation_1-logloss:0.26707
# [79]	validation_0-logloss:0.01755	validation_1-logloss:0.26798
# [80]	validation_0-logloss:0.01745	validation_1-logloss:0.26496
# [81]	validation_0-logloss:0.01736	validation_1-logloss:0.26459
# [82]	validation_0-logloss:0.01728	validation_1-logloss:0.26434
# [83]	validation_0-logloss:0.01719	validation_1-logloss:0.26527
# [84]	validation_0-logloss:0.01710	validation_1-logloss:0.26244
# [85]	validation_0-logloss:0.01702	validation_1-logloss:0.26336
# [86]	validation_0-logloss:0.01694	validation_1-logloss:0.26230
# [87]	validation_0-logloss:0.01686	validation_1-logloss:0.26193
# [88]	validation_0-logloss:0.01678	validation_1-logloss:0.26243
# [89]	validation_0-logloss:0.01671	validation_1-logloss:0.26481
# [90]	validation_0-logloss:0.01663	validation_1-logloss:0.26362
# [91]	validation_0-logloss:0.01656	validation_1-logloss:0.26339
# [92]	validation_0-logloss:0.01650	validation_1-logloss:0.26328
# [93]	validation_0-logloss:0.01643	validation_1-logloss:0.26328
# [94]	validation_0-logloss:0.01636	validation_1-logloss:0.26216
# [95]	validation_0-logloss:0.01629	validation_1-logloss:0.25971
# [96]	validation_0-logloss:0.01623	validation_1-logloss:0.26199
# [97]	validation_0-logloss:0.01616	validation_1-logloss:0.26191
# [98]	validation_0-logloss:0.01610	validation_1-logloss:0.26160
# [99]	validation_0-logloss:0.01603	validation_1-logloss:0.26073
# [100]	validation_0-logloss:0.01597	validation_1-logloss:0.26073
# [101]	validation_0-logloss:0.01591	validation_1-logloss:0.26052
# [102]	validation_0-logloss:0.01584	validation_1-logloss:0.26109
# [103]	validation_0-logloss:0.01579	validation_1-logloss:0.26323
# [104]	validation_0-logloss:0.01573	validation_1-logloss:0.26322
# [105]	validation_0-logloss:0.01568	validation_1-logloss:0.26228
# [106]	validation_0-logloss:0.01562	validation_1-logloss:0.26241
# [107]	validation_0-logloss:0.01555	validation_1-logloss:0.26004
# [108]	validation_0-logloss:0.01550	validation_1-logloss:0.25928
# [109]	validation_0-logloss:0.01544	validation_1-logloss:0.25986
# [110]	validation_0-logloss:0.01538	validation_1-logloss:0.25964
# [111]	validation_0-logloss:0.01533	validation_1-logloss:0.25758
# [112]	validation_0-logloss:0.01528	validation_1-logloss:0.25775
# [113]	validation_0-logloss:0.01522	validation_1-logloss:0.25833
# [114]	validation_0-logloss:0.01517	validation_1-logloss:0.25828
# [115]	validation_0-logloss:0.01512	validation_1-logloss:0.25797
# [116]	validation_0-logloss:0.01507	validation_1-logloss:0.26003
# [117]	validation_0-logloss:0.01502	validation_1-logloss:0.25929
# [118]	validation_0-logloss:0.01497	validation_1-logloss:0.25928
# [119]	validation_0-logloss:0.01493	validation_1-logloss:0.25928
# [120]	validation_0-logloss:0.01487	validation_1-logloss:0.25726
# [121]	validation_0-logloss:0.01483	validation_1-logloss:0.25923
# [122]	validation_0-logloss:0.01479	validation_1-logloss:0.25943
# [123]	validation_0-logloss:0.01474	validation_1-logloss:0.25939
# [124]	validation_0-logloss:0.01469	validation_1-logloss:0.25746
# [125]	validation_0-logloss:0.01465	validation_1-logloss:0.25768
# [126]	validation_0-logloss:0.01461	validation_1-logloss:0.25703
# [127]	validation_0-logloss:0.01456	validation_1-logloss:0.25761
# [128]	validation_0-logloss:0.01452	validation_1-logloss:0.25755
# [129]	validation_0-logloss:0.01448	validation_1-logloss:0.25695
# [130]	validation_0-logloss:0.01444	validation_1-logloss:0.25694
# [131]	validation_0-logloss:0.01440	validation_1-logloss:0.25884
# [132]	validation_0-logloss:0.01436	validation_1-logloss:0.25713
# [133]	validation_0-logloss:0.01432	validation_1-logloss:0.25716
# [134]	validation_0-logloss:0.01429	validation_1-logloss:0.25689
# [135]	validation_0-logloss:0.01425	validation_1-logloss:0.25694
# [136]	validation_0-logloss:0.01421	validation_1-logloss:0.25750
# [137]	validation_0-logloss:0.01417	validation_1-logloss:0.25745
# [138]	validation_0-logloss:0.01413	validation_1-logloss:0.25686
# [139]	validation_0-logloss:0.01410	validation_1-logloss:0.25660
# [140]	validation_0-logloss:0.01406	validation_1-logloss:0.25843
# [141]	validation_0-logloss:0.01403	validation_1-logloss:0.25847
# [142]	validation_0-logloss:0.01400	validation_1-logloss:0.25844
# [143]	validation_0-logloss:0.01396	validation_1-logloss:0.25898
# [144]	validation_0-logloss:0.01393	validation_1-logloss:0.25828
# [145]	validation_0-logloss:0.01390	validation_1-logloss:0.25802
# [146]	validation_0-logloss:0.01387	validation_1-logloss:0.25825
# [147]	validation_0-logloss:0.01384	validation_1-logloss:0.25993
# [148]	validation_0-logloss:0.01380	validation_1-logloss:0.25935
# [149]	validation_0-logloss:0.01377	validation_1-logloss:0.25931
# [150]	validation_0-logloss:0.01374	validation_1-logloss:0.25866
# [151]	validation_0-logloss:0.01370	validation_1-logloss:0.25870
# [152]	validation_0-logloss:0.01368	validation_1-logloss:0.25894
# [153]	validation_0-logloss:0.01365	validation_1-logloss:0.25868
# [154]	validation_0-logloss:0.01362	validation_1-logloss:0.25801
# [155]	validation_0-logloss:0.01359	validation_1-logloss:0.25750
# [156]	validation_0-logloss:0.01356	validation_1-logloss:0.25803
# [157]	validation_0-logloss:0.01353	validation_1-logloss:0.25799
# [158]	validation_0-logloss:0.01350	validation_1-logloss:0.25962
# [159]	validation_0-logloss:0.01347	validation_1-logloss:0.25966
# [160]	validation_0-logloss:0.01344	validation_1-logloss:0.25904
# [161]	validation_0-logloss:0.01342	validation_1-logloss:0.25930
# [162]	validation_0-logloss:0.01339	validation_1-logloss:0.25879
# [163]	validation_0-logloss:0.01336	validation_1-logloss:0.25875
# [164]	validation_0-logloss:0.01333	validation_1-logloss:0.26031
# [165]	validation_0-logloss:0.01331	validation_1-logloss:0.26007
# [166]	validation_0-logloss:0.01329	validation_1-logloss:0.25962
# [167]	validation_0-logloss:0.01326	validation_1-logloss:0.25964
# [168]	validation_0-logloss:0.01324	validation_1-logloss:0.26111
# [169]	validation_0-logloss:0.01321	validation_1-logloss:0.26049
# [170]	validation_0-logloss:0.01319	validation_1-logloss:0.26053
# [171]	validation_0-logloss:0.01316	validation_1-logloss:0.26029
# [172]	validation_0-logloss:0.01314	validation_1-logloss:0.26079
# [173]	validation_0-logloss:0.01312	validation_1-logloss:0.26035
# [174]	validation_0-logloss:0.01310	validation_1-logloss:0.26013
# [175]	validation_0-logloss:0.01308	validation_1-logloss:0.26039
# [176]	validation_0-logloss:0.01306	validation_1-logloss:0.26032
# [177]	validation_0-logloss:0.01303	validation_1-logloss:0.25974
# [178]	validation_0-logloss:0.01301	validation_1-logloss:0.26021
# [179]	validation_0-logloss:0.01299	validation_1-logloss:0.25980
# [180]	validation_0-logloss:0.01297	validation_1-logloss:0.26005
# [181]	validation_0-logloss:0.01295	validation_1-logloss:0.25997
# [182]	validation_0-logloss:0.01294	validation_1-logloss:0.26040
# [183]	validation_0-logloss:0.01292	validation_1-logloss:0.26016
# [184]	validation_0-logloss:0.01290	validation_1-logloss:0.25977
# [185]	validation_0-logloss:0.01288	validation_1-logloss:0.25927
# [186]	validation_0-logloss:0.01286	validation_1-logloss:0.25951
# [187]	validation_0-logloss:0.01284	validation_1-logloss:0.25943
# [188]	validation_0-logloss:0.01283	validation_1-logloss:0.25921
# [189]	validation_0-logloss:0.01282	validation_1-logloss:0.25883
# 오차 행렬
# [[34  3]
#  [ 3 74]]
# 정확도: 0.9474, 정밀도: 0.9610, 재현율: 0.9610,    F1: 0.9610, AUC:0.9923

# %% [markdown]
# # 분류 실습 - 캐글 신용카드 사기 검출

# %% [markdown]
# ## 데이터 일차 가공 및 모델 학습/예측/평가

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

card_df = pd.read_csv('./creditcard.csv')
card_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Dropping Time
from sklearn.model_selection import train_test_split

def get_preprocessed_df(df=None):
    df_copy = df.copy()
    df_copy.drop('Time', axis=1, inplace=True)
    return df_copy

# %%
# Split dataset into Train & Test
def get_train_test_dataset(df=None):
    df_copy = get_preprocessed_df(df)
    X_features = df_copy.iloc[:, :-1]
    y_target = df_copy.iloc[:, -1]
    X_train, X_test, y_train, y_test = \
    train_test_split(X_features, y_target, test_size=0.3, random_state=0, stratify=y_target)
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = get_train_test_dataset(card_df)

# %%
print('학습 데이터 레이블 값 비율')
print(y_train.value_counts()/y_train.shape[0] * 100)
print('테스트 데이터 레이블 값 비율')
print(y_test.value_counts()/y_test.shape[0] * 100)
# Out:
# 학습 데이터 레이블 값 비율
# 0    99.827451
# 1     0.172549
# Name: Class, dtype: float64
# 테스트 데이터 레이블 값 비율
# 0    99.826785
# 1     0.173215
# Name: Class, dtype: float64

# %%
# Using LogisticRegression
from sklearn.linear_model import LogisticRegression

# Train
lr_clf = LogisticRegression()
lr_clf.fit(X_train, y_train)
# Predict
lr_pred = lr_clf.predict(X_test)
lr_pred_proba = lr_clf.predict_proba(X_test)[:, 1]

# Evaluate
get_clf_eval(y_test, lr_pred, lr_pred_proba)
# Out:
# 오차 행렬
# [[85283    12]
#  [   58    90]]
# 정확도: 0.9992, 정밀도: 0.8824, 재현율: 0.6081,    F1: 0.7200, AUC:0.9632

# %%
# Make training process as a function
def get_model_train_eval(model, ftr_train=None, ftr_test=None, tgt_train=None, tgt_test=None):
    model.fit(ftr_train, tgt_train)
    pred = model.predict(ftr_test)
    pred_proba = model.predict_proba(ftr_test)[:, 1]
    get_clf_eval(tgt_test, pred, pred_proba)

# %%
# Using LightGBM
from lightgbm import LGBMClassifier
# Train & Evaluate
lgbm_clf = LGBMClassifier(n_estimators=1000, num_leaves=64, n_jobs=-1, boost_from_average=False)
get_model_train_eval(lgbm_clf, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)
# Out:
# 오차 행렬
# [[85290     5]
#  [   36   112]]
# 정확도: 0.9995, 정밀도: 0.9573, 재현율: 0.7568,    F1: 0.8453, AUC:0.9790

# %% [markdown]
# ## 데이터 분포도 변환 후 모델 학습/예측/평가

# %%
# Distribution of Amount Feature
import seaborn as sns

plt.figure(figsize=(8, 4))
plt.xticks(range(0, 30000, 1000), rotation=60)
sns.histplot(card_df['Amount'], bins=100, kde=True)
plt.show()

# %%
# Data Preprocessing
from sklearn.preprocessing import StandardScaler
def get_preprocessed_df(df=None):
    df_copy = df.copy()
    scaler = StandardScaler()
    amount_n = scaler.fit_transform(df_copy['Amount'].values.reshape(-1, 1))
    df_copy.insert(0, 'Amount_Scaled', amount_n)
    df_copy.drop(['Time','Amount'], axis=1, inplace=True)
    return df_copy

# %%
# Train & Evaluate with LogisticRegression & LGBMClassifier
X_train, X_test, y_train, y_test = get_train_test_dataset(card_df)

print('### 로지스틱 회귀 예측 성능 ###')
lr_clf = LogisticRegression()
get_model_train_eval(lr_clf, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)

print('### LightGBM 예측 성능 ###')
lgbm_clf = LGBMClassifier(n_estimators=1000, num_leaves=64, n_jobs=-1, boost_from_average=False)
get_model_train_eval(lgbm_clf, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)
# Out:
# ### 로지스틱 회귀 예측 성능 ###
# 오차 행렬
# [[85281    14]
#  [   58    90]]
# 정확도: 0.9992, 정밀도: 0.8654, 재현율: 0.6081,    F1: 0.7143, AUC:0.9702
# ### LightGBM 예측 성능 ###
# 오차 행렬
# [[85290     5]
#  [   37   111]]
# 정확도: 0.9995, 정밀도: 0.9569, 재현율: 0.7500,    F1: 0.8409, AUC:0.9779

# %%
# Changing Amount into log
def get_preprocessed_df(df=None):
    df_copy = df.copy()
    amount_n = np.log1p(df_copy['Amount'])
    df_copy.insert(0, 'Amount_Scaled', amount_n)
    df_copy.drop(['Time','Amount'], axis=1, inplace=True)
    return df_copy

# %%
# Train again with Amount as log
X_train, X_test, y_train, y_test = get_train_test_dataset(card_df)

print('### 로지스틱 회귀 예측 성능 ###')
get_model_train_eval(lr_clf, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)

print('### LightGBM 예측 성능 ###')
get_model_train_eval(lgbm_clf, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)
# Out:
# ### 로지스틱 회귀 예측 성능 ###
# 오차 행렬
# [[85283    12]
#  [   59    89]]
# 정확도: 0.9992, 정밀도: 0.8812, 재현율: 0.6014,    F1: 0.7149, AUC:0.9727
# ### LightGBM 예측 성능 ###
# 오차 행렬
# [[85290     5]
#  [   35   113]]
# 정확도: 0.9995, 정밀도: 0.9576, 재현율: 0.7635,    F1: 0.8496, AUC:0.9796

# %% [markdown]
# ## 이상치 데이터 제거 후 모델 학습/예측/평가

# %%
# Plotting correlation
import seaborn as sns

plt.figure(figsize=(9, 9))
corr = card_df.corr()
sns.heatmap(corr, cmap='RdBu')
# Out:
# <Axes: >

# %%
# Find Outliers
import numpy as np

def get_outlier(df=None, column=None, weight=1.5):
    fraud = df[df['Class']==1][column]
    quantile_25 = np.percentile(fraud.values, 25)
    quantile_75 = np.percentile(fraud.values, 75)
    iqr = quantile_75 - quantile_25
    iqr_weight = iqr * weight
    lowest_val = quantile_25 - iqr_weight
    highest_val = quantile_75 + iqr_weight
    outlier_index = fraud[(fraud < lowest_val) | (fraud > highest_val)].index
    return outlier_index

# %%
outlier_index = get_outlier(df=card_df, column='V14', weight=1.5)
print('이상치 데이터 인덱스:', outlier_index)
# Out:
# 이상치 데이터 인덱스: Int64Index([8296, 8615, 9035, 9252], dtype='int64')

# %%
# Remove outliers of V14 feature
def get_preprocessed_df(df=None):
    df_copy = df.copy()
    amount_n = np.log1p(df_copy['Amount'])
    df_copy.insert(0, 'Amount_Scaled', amount_n)
    df_copy.drop(['Time','Amount'], axis=1, inplace=True)
    # 이상치 데이터 삭제하는 로직 추가
    outlier_index = get_outlier(df=df_copy, column='V14', weight=1.5)
    df_copy.drop(outlier_index, axis=0, inplace=True)
    return df_copy

X_train, X_test, y_train, y_test = get_train_test_dataset(card_df)
print('### 로지스틱 회귀 예측 성능 ###')
get_model_train_eval(lr_clf, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)
print('### LightGBM 예측 성능 ###')
get_model_train_eval(lgbm_clf, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)
# Out:
# ### 로지스틱 회귀 예측 성능 ###
# 오차 행렬
# [[85281    14]
#  [   48    98]]
# 정확도: 0.9993, 정밀도: 0.8750, 재현율: 0.6712,    F1: 0.7597, AUC:0.9743
# ### LightGBM 예측 성능 ###
# 오차 행렬
# [[85290     5]
#  [   25   121]]
# 정확도: 0.9996, 정밀도: 0.9603, 재현율: 0.8288,    F1: 0.8897, AUC:0.9780

# %% [markdown]
# ## SMOTE 오버 샘플링 적용 후 모델 학습/예측/평가

# %%
# Using SMOTE
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=0)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트: ', X_train.shape, y_train.shape)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트: ', X_train_over.shape, y_train_over.shape)
print('SMOTE 적용 후 레이블 값 분포: \n', pd.Series(y_train_over).value_counts())
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트:  (199362, 29) (199362,)
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트:  (398040, 29) (398040,)
# SMOTE 적용 후 레이블 값 분포:
#  0    199020
# 1    199020
# Name: Class, dtype: int64

# %%
# Train with LogisticRegression
lr_clf = LogisticRegression()
get_model_train_eval(lr_clf, ftr_train=X_train_over, ftr_test=X_test, tgt_train=y_train_over, tgt_test=y_test)
# Out:
# 오차 행렬
# [[82937  2358]
#  [   11   135]]
# 정확도: 0.9723, 정밀도: 0.0542, 재현율: 0.9247,    F1: 0.1023, AUC:0.9737

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.metrics import precision_recall_curve
# %matplotlib inline

def precision_recall_curve_plot(y_test , pred_proba_c1):
    precisions, recalls, thresholds = precision_recall_curve( y_test, pred_proba_c1)
    
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend(); plt.grid()
    plt.show()

# %%
# Plotting Precision vs Recall
precision_recall_curve_plot( y_test, lr_clf.predict_proba(X_test)[:, 1] )

# %%
# Train Test Evaluate LightGBM with oversampling data
lgbm_clf = LGBMClassifier(n_estimators=1000, num_leaves=64, n_jobs=-1, boost_from_average=False)
get_model_train_eval(lgbm_clf, ftr_train=X_train_over, ftr_test=X_test,
                  tgt_train=y_train_over, tgt_test=y_test)
# Out:
# 오차 행렬
# [[85283    12]
#  [   22   124]]
# 정확도: 0.9996, 정밀도: 0.9118, 재현율: 0.8493,    F1: 0.8794, AUC:0.9814

# %% [markdown]
# # 스태킹 앙상블

# %%
import numpy as np

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cancer_data = load_breast_cancer()

X_data = cancer_data.data
y_label = cancer_data.target

X_train , X_test , y_train , y_test = train_test_split(X_data , y_label , test_size=0.2 , random_state=0)

# %%
# Individual Classifiers
knn_clf  = KNeighborsClassifier(n_neighbors=4)
rf_clf = RandomForestClassifier(n_estimators=100, random_state=0)
dt_clf = DecisionTreeClassifier()
ada_clf = AdaBoostClassifier(n_estimators=100)

# Classifier for Final Stacking Model
lr_final = LogisticRegression(C=10)

# %%
# Train individual models
knn_clf.fit(X_train, y_train)
rf_clf.fit(X_train , y_train)
dt_clf.fit(X_train , y_train)
ada_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
# Predict
knn_pred = knn_clf.predict(X_test)
rf_pred = rf_clf.predict(X_test)
dt_pred = dt_clf.predict(X_test)
ada_pred = ada_clf.predict(X_test)

print('KNN 정확도: {0:.4f}'.format(accuracy_score(y_test, knn_pred)))
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy_score(y_test, rf_pred)))
print('결정 트리 정확도: {0:.4f}'.format(accuracy_score(y_test, dt_pred)))
print('에이다부스트 정확도: {0:.4f} :'.format(accuracy_score(y_test, ada_pred)))
# Out:
# KNN 정확도: 0.9211
# 랜덤 포레스트 정확도: 0.9649
# 결정 트리 정확도: 0.9035
# 에이다부스트 정확도: 0.9561 :

# %%
# Make Feature
pred = np.array([knn_pred, rf_pred, dt_pred, ada_pred])
print(pred.shape)

pred = np.transpose(pred)
print(pred.shape)
# Out:
# (4, 114)
# (114, 4)

# %%
# Train 
lr_final.fit(pred, y_test)
# Predict
final = lr_final.predict(pred)
# Evaluate
print('최종 메타 모델의 예측 정확도: {0:.4f}'.format(accuracy_score(y_test , final)))
# Out:
# 최종 메타 모델의 예측 정확도: 0.9737

# %% [markdown]
# ## CV 세트 기반의 스태킹

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error

def get_stacking_base_datasets(model, X_train_n, y_train_n, X_test_n, n_folds ):
    kf = KFold(n_splits=n_folds, shuffle=False)
    train_fold_pred = np.zeros((X_train_n.shape[0] ,1 ))
    test_pred = np.zeros((X_test_n.shape[0],n_folds))
    print(model.__class__.__name__ , ' model 시작 ')
    
    for folder_counter , (train_index, valid_index) in enumerate(kf.split(X_train_n)):
        print('\t 폴드 세트: ',folder_counter,' 시작 ')
        X_tr = X_train_n[train_index] 
        y_tr = y_train_n[train_index] 
        X_te = X_train_n[valid_index]  
        
        model.fit(X_tr , y_tr)       
        train_fold_pred[valid_index, :] = model.predict(X_te).reshape(-1,1)
        test_pred[:, folder_counter] = model.predict(X_test_n)
            
    test_pred_mean = np.mean(test_pred, axis=1).reshape(-1,1)    
    
    return train_fold_pred , test_pred_mean

# %%
# Create Individual models
knn_train, knn_test = get_stacking_base_datasets(knn_clf, X_train, y_train, X_test, 7)
rf_train, rf_test = get_stacking_base_datasets(rf_clf, X_train, y_train, X_test, 7)
dt_train, dt_test = get_stacking_base_datasets(dt_clf, X_train, y_train, X_test,  7)    
ada_train, ada_test = get_stacking_base_datasets(ada_clf, X_train, y_train, X_test, 7)
# Out:
# KNeighborsClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# RandomForestClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# DecisionTreeClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# AdaBoostClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작

# %%
# Make Train & Test dataset
Stack_final_X_train = np.concatenate((knn_train, rf_train, dt_train, ada_train), axis=1)
Stack_final_X_test = np.concatenate((knn_test, rf_test, dt_test, ada_test), axis=1)
print('원본 학습 피처 데이터 Shape:',X_train.shape, '원본 테스트 피처 Shape:',X_test.shape)
print('스태킹 학습 피처 데이터 Shape:', Stack_final_X_train.shape,
      '스태킹 테스트 피처 데이터 Shape:',Stack_final_X_test.shape)
# Out:
# 원본 학습 피처 데이터 Shape: (455, 30) 원본 테스트 피처 Shape: (114, 30)
# 스태킹 학습 피처 데이터 Shape: (455, 4) 스태킹 테스트 피처 데이터 Shape: (114, 4)

# %%
# Train
lr_final.fit(Stack_final_X_train, y_train)
# Test
stack_final = lr_final.predict(Stack_final_X_test)
# Predict
print('최종 메타 모델의 예측 정확도: {0:.4f}'.format(accuracy_score(y_test, stack_final)))
# Out:
# 최종 메타 모델의 예측 정확도: 0.9737
